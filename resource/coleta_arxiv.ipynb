# %% [markdown]
# # Trabalho Prático de IA - Notebook base de coleta de dados do ArXiv
#
# **Disciplina:** Inteligência Artificial - PPGCC - FACOM/UFMS
# **Professor:** Bruno M. Nogueira
# **Semestre:** 2026/1
#
# Este notebook é um **ponto de partida** para o trabalho prático. Ele mostra como **coletar artigos do ArXiv** filtrando por categorias e palavras-chave relacionadas ao seu tema de pesquisa, normalizar os metadados e salvar uma coleção em `JSONL`.
#
# Você é **livre (e encorajado)** para modificar este código: trocar a API, ajustar os filtros, adicionar campos, etc. O notebook serve apenas para que você não perca tempo na parte mais mecânica do trabalho.
#
# **Atenção:** a etapa de coleta deve ser justificada no relatório (escolha do tema, palavras-chave, categorias, janela temporal). Veja a Seção 3-(a) do enunciado e o exemplo lá fornecido.
#
# > **A API do ArXiv é instável.** Não é incomum ver erros `HTTP 429` ("too many requests") ou `HTTP 503` ("service unavailable"), especialmente em queries longas ou em horários de pico. Este notebook implementa **retry com backoff exponencial e retomada por offset**, e o arquivo de saída preserva o progresso. Se a célula de coleta falhar, basta **rodar a mesma célula novamente** mais tarde, ela continua de onde parou. Não existe "chave de API" do ArXiv: o limite é por IP.

# %% [markdown]
# ## 1. Instalação de dependências
#
# Vamos usar a biblioteca [`arxiv`](https://pypi.org/project/arxiv/), um *wrapper* sobre a API oficial do ArXiv que já cuida de paginação e *rate limiting* básico. Também usamos `pandas` para inspeção tabular.

# %%
# Execute apenas uma vez, descomentando se necessário.
# !pip install arxiv pandas tqdm

# %%
import json
import os
import time
from datetime import datetime, timezone
from pathlib import Path

import arxiv
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ## 2. Configuração da coleta (você edita aqui!)
#
# Adapte os campos abaixo ao **seu** tema de pesquisa. O exemplo segue o caso do enunciado ("Detecção de fraudes em transações financeiras com aprendizado profundo").
#
# **Dica para reduzir erros 429/503:** use `PAGE_SIZE = 50` (em vez de 100), evite horários de pico (manhã EUA) e mantenha as palavras-chave razoavelmente concisas. Queries muito longas (muitos `OR`) tendem a falhar mais.

# %%
# -----------------------------------------------------------------------------
# DEFINA AQUI O ESCOPO DA SUA COLEÇÃO
# -----------------------------------------------------------------------------

# Palavras-chave / frases que descrevem o seu tema. Serão buscadas em
# título e abstract (operador 'all:' do ArXiv).
KEYWORDS = [
    "fraud detection",
    "anomaly detection",
    "credit card fraud",
    "financial transactions",
    "money laundering",
]

# Categorias do ArXiv a considerar (lista em https://arxiv.org/category_taxonomy).
# Use [] para não restringir por categoria.
CATEGORIES = ["cs.LG", "cs.CR", "stat.ML"]

# Janela temporal (ano de submissão). Use None para não restringir.
YEAR_FROM = 2018
YEAR_TO = 2026

# Tamanho-alvo aproximado da coleção (entre 1000 e 5000, conforme enunciado).
TARGET_SIZE = 2000

# Tamanho de cada página retornada pela API.
# 50 costuma ser mais robusto contra HTTP 429/503 do que 100.
PAGE_SIZE = 50

# Caminho de saída da coleção bruta.
OUTPUT_DIR = Path("./data")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
RAW_PATH = OUTPUT_DIR / "arxiv_raw.jsonl"
CORPUS_PATH = OUTPUT_DIR / "corpus.jsonl"

print("Configuração carregada.")
print(" - Keywords  :", KEYWORDS)
print(" - Categories:", CATEGORIES)
print(" - Years     :", YEAR_FROM, "->", YEAR_TO)
print(" - Target    :", TARGET_SIZE)
print(" - PageSize  :", PAGE_SIZE)
# Out:
# Configuração carregada.
#  - Keywords  : ['fraud detection', 'anomaly detection', 'credit card fraud', 'financial transactions', 'money laundering']
#  - Categories: ['cs.LG', 'cs.CR', 'stat.ML']
#  - Years     : 2018 -> 2026
#  - Target    : 2000
#  - PageSize  : 50

# %% [markdown]
# ## 3. Coleta paginada via API do ArXiv (com retry/backoff)
#
# A função abaixo monta uma *query* combinando palavras-chave (com `OR`) e categorias (com `OR`), e itera sobre os resultados em ordem decrescente de data de submissão.
#
# **Como ela trata erros HTTP 429 (rate limit) e 503 (serviço indisponível):**
# - Configura o cliente do `arxiv` com `delay_seconds=5` e `num_retries=8` --- mais paciente que o padrão.
# - Encapsula a iteração em um *loop externo* com **backoff exponencial**: 60s → 120s → 240s → 480s → 600s entre tentativas.
# - Mantém um *offset* de onde paramos: se cair, retoma a partir do mesmo ponto (sem re-baixar tudo).
# - Salva incrementalmente em `arxiv_raw.jsonl` e *deduplica* por `arxiv_id`. **Você pode rodar a célula de coleta várias vezes** --- o progresso é preservado.
#
# **Se mesmo assim não funcionar:** espere 15–30 minutos e tente de novo (o seu IP pode estar temporariamente bloqueado), ou reduza `PAGE_SIZE` para 25 e/ou diminua o número de palavras-chave.

# %%
def build_query(keywords, categories):
    """Monta a string de query no formato esperado pela API do ArXiv."""
    kw_part = " OR ".join([f'all:"{k}"' for k in keywords]) if keywords else ""
    cat_part = " OR ".join([f"cat:{c}" for c in categories]) if categories else ""

    parts = [p for p in [f"({kw_part})" if kw_part else "",
                          f"({cat_part})" if cat_part else ""] if p]
    return " AND ".join(parts) if parts else "all:*"


QUERY = build_query(KEYWORDS, CATEGORIES)
print("Query final:\n", QUERY)
# Out:
# Query final:
#  (all:"fraud detection" OR all:"anomaly detection" OR all:"credit card fraud" OR all:"financial transactions" OR all:"money laundering") AND (cat:cs.LG OR cat:cs.CR OR cat:stat.ML)

# %%
def already_collected_ids(path: Path) -> set:
    """Lê o arquivo .jsonl (se existir) e retorna os IDs já salvos."""
    if not path.exists():
        return set()
    ids = set()
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            try:
                ids.add(json.loads(line)["arxiv_id"])
            except Exception:
                continue
    return ids


def collect_arxiv(query, target_size, page_size, year_from, year_to,
                   out_path: Path,
                   max_outer_attempts: int = 6,
                   initial_backoff_seconds: int = 60):
    """Coleta artigos do ArXiv, salvando incrementalmente em JSONL.

    Robusto contra erros HTTP 429/503 da API do ArXiv:
    - Retry interno do cliente `arxiv` (delay_seconds=5, num_retries=8).
    - Loop externo com backoff exponencial caso a iteração falhe.
    - Retoma do mesmo offset após cada falha, sem re-baixar páginas inteiras.
    """
    client = arxiv.Client(page_size=page_size, delay_seconds=5, num_retries=8)

    seen = already_collected_ids(out_path)
    print(f"Já coletados anteriormente: {len(seen)} artigos.")

    saved_this_run = 0
    offset = 0          # quantos resultados já consumimos da API
    outer_attempt = 0   # quantas vezes o loop externo tentou

    while len(seen) < target_size and outer_attempt < max_outer_attempts:
        try:
            search = arxiv.Search(
                query=query,
                max_results=target_size * 3,  # 3x para sobrar margem após filtros
                sort_by=arxiv.SortCriterion.SubmittedDate,
                sort_order=arxiv.SortOrder.Descending,
            )

            print(f"\nIniciando/retomando do offset={offset} "
                  f"(salvos={len(seen)}, meta={target_size}).")

            with open(out_path, "a", encoding="utf-8") as f:
                pbar = tqdm(initial=len(seen), total=target_size,
                            desc="coletando")
                for result in client.results(search, offset=offset):
                    offset += 1
                    year = result.published.year if result.published else None
                    if year_from is not None and (year is None or year < year_from):
                        continue
                    if year_to is not None and (year is None or year > year_to):
                        continue

                    arxiv_id = result.get_short_id().split("v")[0]
                    if arxiv_id in seen:
                        continue

                    record = {
                        "arxiv_id": arxiv_id,
                        "title": (result.title or "").strip(),
                        "abstract": (result.summary or "").strip().replace("\n", " "),
                        "authors": [a.name for a in result.authors],
                        "categories": list(result.categories or []),
                        "primary_category": result.primary_category,
                        "published": result.published.isoformat() if result.published else None,
                        "updated": result.updated.isoformat() if result.updated else None,
                        "doi": result.doi,
                        "pdf_url": result.pdf_url,
                        "entry_id": result.entry_id,
                    }
                    f.write(json.dumps(record, ensure_ascii=False) + "\n")
                    f.flush()
                    seen.add(arxiv_id)
                    saved_this_run += 1
                    pbar.update(1)
                    pbar.set_postfix(offset=offset)

                    if len(seen) >= target_size:
                        break
                pbar.close()

            # Se chegou aqui sem exception, terminou normalmente.
            break

        except Exception as e:
            outer_attempt += 1
            wait = min(initial_backoff_seconds * (2 ** (outer_attempt - 1)), 600)
            print(f"\n[aviso] coleta interrompida (tentativa {outer_attempt}/"
                  f"{max_outer_attempts}): {type(e).__name__}: {e}")
            print(f"[aviso] aguardando {wait}s antes de retomar do offset={offset}...")
            for _ in tqdm(range(wait), desc="backoff", leave=False):
                time.sleep(1)

    print(f"\nColeta finalizada. Total acumulado em {out_path}: {len(seen)} artigos.")
    if len(seen) < target_size:
        print(f"[atenção] Não atingiu a meta de {target_size} (parou em {len(seen)}).")
        print( "[atenção] Você pode rodar esta célula novamente para continuar de onde parou.")
    return len(seen)

# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     n = collect_arxiv(
    query=QUERY,
    target_size=TARGET_SIZE,
    page_size=PAGE_SIZE,
    year_from=YEAR_FROM,
    year_to=YEAR_TO,
    out_path=RAW_PATH,
)
n
# Out:
# Já coletados anteriormente: 50 artigos.
#
# Iniciando/retomando do offset=0 (salvos=50, meta=2000).
# coletando:   2%|▎         | 50/2000 [00:00<?, ?it/s]
# coletando:   3%|▎         | 51/2000 [00:06<3:21:15,  6.20s/it]
# coletando:   3%|▎         | 51/2000 [00:06<3:21:15,  6.20s/it, offset=51]
# coletando:   3%|▎         | 52/2000 [00:06<3:21:08,  6.20s/it, offset=52]
# coletando:   3%|▎         | 53/2000 [00:06<3:21:02,  6.20s/it, offset=53]
# coletando:   3%|▎         | 54/2000 [00:06<3:20:56,  6.20s/it, offset=54]
# coletando:   3%|▎         | 55/2000 [00:06<3:20:50,  6.20s/it, offset=55]
# coletando:   3%|▎         | 56/2000 [00:06<3:20:44,  6.20s/it, offset=56]
# coletando:   3%|▎         | 57/2000 [00:06<3:20:37,  6.20s/it, offset=57]
# coletando:   3%|▎         | 58/2000 [00:06<3:20:31,  6.20s/it, offset=58]
# coletando:   3%|▎         | 59/2000 [00:06<3:20:25,  6.20s/it, offset=59]
# coletando:   3%|▎         | 60/2000 [00:06<3:20:19,  6.20s/it, offset=60]
# coletando:   3%|▎         | 61/2000 [00:06<3:20:13,  6.20s/it, offset=61]
# coletando:   3%|▎         | 62/2000 [00:06<3:20:06,  6.20s/it, offset=62]
# coletando:   3%|▎         | 63/2000 [00:06<3:20:00,  6.20s/it, offset=63]
# coletando:   3%|▎         | 64/2000 [00:06<3:19:54,  6.20s/it, offset=64]
# coletando:   3%|▎         | 65/2000 [00:06<3:19:48,  6.20s/it, offset=65]
# coletando:   3%|▎         | 66/2000 [00:06<3:19:42,  6.20s/it, offset=66]
# coletando:   3%|▎         | 67/2000 [00:06<3:19:35,  6.20s/it, offset=67]
# coletando:   3%|▎         | 68/2000 [00:06<3:19:29,  6.20s/it, offset=68]
# coletando:   3%|▎         | 69/2000 [00:06<3:19:23,  6.20s/it, offset=69]
# coletando:   4%|▎         | 70/2000 [00:06<3:19:17,  6.20s/it, offset=70]
# coletando:   4%|▎         | 71/2000 [00:06<3:19:11,  6.20s/it, offset=71]
# coletando:   4%|▎         | 72/2000 [00:06<3:19:04,  6.20s/it, offset=72]
# coletando:   4%|▎         | 73/2000 [00:06<3:18:58,  6.20s/it, offset=73]
# coletando:   4%|▎         | 74/2000 [00:06<3:18:52,  6.20s/it, offset=74]
# coletando:   4%|▍         | 75/2000 [00:06<3:18:46,  6.20s/it, offset=75]
# coletando:   4%|▍         | 76/2000 [00:06<3:18:40,  6.20s/it, offset=76]
# coletando:   4%|▍         | 77/2000 [00:06<3:18:33,  6.20s/it, offset=77]
# coletando:   4%|▍         | 78/2000 [00:06<3:18:27,  6.20s/it, offset=78]
# coletando:   4%|▍         | 79/2000 [00:06<3:18:21,  6.20s/it, offset=79]
# coletando:   4%|▍         | 80/2000 [00:06<3:18:15,  6.20s/it, offset=80]
# coletando:   4%|▍         | 81/2000 [00:06<3:18:09,  6.20s/it, offset=81]
# coletando:   4%|▍         | 82/2000 [00:06<3:18:02,  6.20s/it, offset=82]
# coletando:   4%|▍         | 83/2000 [00:06<3:17:56,  6.20s/it, offset=83]
# coletando:   4%|▍         | 84/2000 [00:06<3:17:50,  6.20s/it, offset=84]
# coletando:   4%|▍         | 85/2000 [00:06<3:17:44,  6.20s/it, offset=85]
# coletando:   4%|▍         | 86/2000 [00:06<3:17:38,  6.20s/it, offset=86]
# coletando:   4%|▍         | 87/2000 [00:06<3:17:32,  6.20s/it, offset=87]
# coletando:   4%|▍         | 88/2000 [00:06<3:17:25,  6.20s/it, offset=88]
# coletando:   4%|▍         | 89/2000 [00:06<3:17:19,  6.20s/it, offset=89]
# coletando:   4%|▍         | 90/2000 [00:06<3:17:13,  6.20s/it, offset=90]
# coletando:   5%|▍         | 91/2000 [00:06<3:17:07,  6.20s/it, offset=91]
# coletando:   5%|▍         | 92/2000 [00:06<3:17:01,  6.20s/it, offset=92]
# coletando:   5%|▍         | 93/2000 [00:06<3:16:54,  6.20s/it, offset=93]
# coletando:   5%|▍         | 94/2000 [00:06<3:16:48,  6.20s/it, offset=94]
# coletando:   5%|▍         | 95/2000 [00:06<3:16:42,  6.20s/it, offset=95]
# coletando:   5%|▍         | 96/2000 [00:06<3:16:36,  6.20s/it, offset=96]
# coletando:   5%|▍         | 97/2000 [00:06<3:16:30,  6.20s/it, offset=97]
# coletando:   5%|▍         | 98/2000 [00:06<3:16:23,  6.20s/it, offset=98]
# coletando:   5%|▍         | 99/2000 [00:06<3:16:17,  6.20s/it, offset=99]
# coletando:   5%|▌         | 100/2000 [00:06<3:16:11,  6.20s/it, offset=100]
# coletando:   5%|▌         | 101/2000 [00:12<06:27,  4.90it/s, offset=100]
# coletando:   5%|▌         | 101/2000 [00:12<06:27,  4.90it/s, offset=101]
# coletando:   5%|▌         | 102/2000 [00:12<06:27,  4.90it/s, offset=102]
# coletando:   5%|▌         | 103/2000 [00:12<06:27,  4.90it/s, offset=103]
# coletando:   5%|▌         | 104/2000 [00:12<06:26,  4.90it/s, offset=104]
# coletando:   5%|▌         | 105/2000 [00:12<06:26,  4.90it/s, offset=105]
# coletando:   5%|▌         | 106/2000 [00:12<06:26,  4.90it/s, offset=106]
# coletando:   5%|▌         | 107/2000 [00:12<06:26,  4.90it/s, offset=107]
# coletando:   5%|▌         | 108/2000 [00:12<06:26,  4.90it/s, offset=108]
# coletando:   5%|▌         | 109/2000 [00:12<06:25,  4.90it/s, offset=109]
# coletando:   6%|▌         | 110/2000 [00:12<06:25,  4.90it/s, offset=110]
# coletando:   6%|▌         | 111/2000 [00:12<06:25,  4.90it/s, offset=111]
# coletando:   6%|▌         | 112/2000 [00:12<06:25,  4.90it/s, offset=112]
# coletando:   6%|▌         | 113/2000 [00:12<06:25,  4.90it/s, offset=113]
# coletando:   6%|▌         | 114/2000 [00:12<06:24,  4.90it/s, offset=114]
# coletando:   6%|▌         | 115/2000 [00:12<06:24,  4.90it/s, offset=115]
# coletando:   6%|▌         | 116/2000 [00:12<06:24,  4.90it/s, offset=116]
# coletando:   6%|▌         | 117/2000 [00:12<06:24,  4.90it/s, offset=117]
# coletando:   6%|▌         | 118/2000 [00:12<06:24,  4.90it/s, offset=118]
# coletando:   6%|▌         | 119/2000 [00:12<06:23,  4.90it/s, offset=119]
# coletando:   6%|▌         | 120/2000 [00:12<06:23,  4.90it/s, offset=120]
# coletando:   6%|▌         | 121/2000 [00:12<06:23,  4.90it/s, offset=121]
# coletando:   6%|▌         | 122/2000 [00:12<06:23,  4.90it/s, offset=122]
# coletando:   6%|▌         | 123/2000 [00:12<06:23,  4.90it/s, offset=123]
# coletando:   6%|▌         | 124/2000 [00:12<06:22,  4.90it/s, offset=124]
# coletando:   6%|▋         | 125/2000 [00:12<06:22,  4.90it/s, offset=125]
# coletando:   6%|▋         | 126/2000 [00:12<06:22,  4.90it/s, offset=126]
# coletando:   6%|▋         | 127/2000 [00:12<06:22,  4.90it/s, offset=127]
# coletando:   6%|▋         | 128/2000 [00:12<06:22,  4.90it/s, offset=128]
# coletando:   6%|▋         | 129/2000 [00:12<06:21,  4.90it/s, offset=129]
# coletando:   6%|▋         | 130/2000 [00:12<06:21,  4.90it/s, offset=130]
# coletando:   7%|▋         | 131/2000 [00:12<06:21,  4.90it/s, offset=131]
# coletando:   7%|▋         | 132/2000 [00:12<06:21,  4.90it/s, offset=132]
# coletando:   7%|▋         | 133/2000 [00:12<06:21,  4.90it/s, offset=133]
# coletando:   7%|▋         | 134/2000 [00:12<06:20,  4.90it/s, offset=134]
# coletando:   7%|▋         | 135/2000 [00:12<06:20,  4.90it/s, offset=135]
# coletando:   7%|▋         | 136/2000 [00:12<06:20,  4.90it/s, offset=136]
# coletando:   7%|▋         | 137/2000 [00:12<06:20,  4.90it/s, offset=137]
# coletando:   7%|▋         | 138/2000 [00:12<06:20,  4.90it/s, offset=138]
# coletando:   7%|▋         | 139/2000 [00:12<06:19,  4.90it/s, offset=139]
# coletando:   7%|▋         | 140/2000 [00:12<06:19,  4.90it/s, offset=140]
# coletando:   7%|▋         | 141/2000 [00:12<06:19,  4.90it/s, offset=141]
# coletando:   7%|▋         | 142/2000 [00:12<06:19,  4.90it/s, offset=142]
# coletando:   7%|▋         | 143/2000 [00:12<06:18,  4.90it/s, offset=143]
# coletando:   7%|▋         | 144/2000 [00:12<06:18,  4.90it/s, offset=144]
# coletando:   7%|▋         | 145/2000 [00:12<06:18,  4.90it/s, offset=145]
# coletando:   7%|▋         | 146/2000 [00:12<06:18,  4.90it/s, offset=146]
# coletando:   7%|▋         | 147/2000 [00:12<06:18,  4.90it/s, offset=147]
# coletando:   7%|▋         | 148/2000 [00:12<06:17,  4.90it/s, offset=148]
# coletando:   7%|▋         | 149/2000 [00:12<06:17,  4.90it/s, offset=149]
# coletando:   8%|▊         | 150/2000 [00:12<06:17,  4.90it/s, offset=150]
# coletando:   8%|▊         | 151/2000 [00:18<04:49,  6.39it/s, offset=150]
# coletando:   8%|▊         | 151/2000 [00:18<04:49,  6.39it/s, offset=151]
# coletando:   8%|▊         | 152/2000 [00:18<04:49,  6.39it/s, offset=152]
# coletando:   8%|▊         | 153/2000 [00:18<04:48,  6.39it/s, offset=153]
# coletando:   8%|▊         | 154/2000 [00:18<04:48,  6.39it/s, offset=154]
# coletando:   8%|▊         | 155/2000 [00:18<04:48,  6.39it/s, offset=155]
# coletando:   8%|▊         | 156/2000 [00:18<04:48,  6.39it/s, offset=156]
# coletando:   8%|▊         | 157/2000 [00:18<04:48,  6.39it/s, offset=157]
# coletando:   8%|▊         | 158/2000 [00:18<04:48,  6.39it/s, offset=158]
# coletando:   8%|▊         | 159/2000 [00:18<04:48,  6.39it/s, offset=159]
# coletando:   8%|▊         | 160/2000 [00:18<04:47,  6.39it/s, offset=160]
# coletando:   8%|▊         | 161/2000 [00:18<04:47,  6.39it/s, offset=161]
# coletando:   8%|▊         | 162/2000 [00:18<04:47,  6.39it/s, offset=162]
# coletando:   8%|▊         | 163/2000 [00:18<04:47,  6.39it/s, offset=163]
# coletando:   8%|▊         | 164/2000 [00:18<04:47,  6.39it/s, offset=164]
# coletando:   8%|▊         | 165/2000 [00:18<04:47,  6.39it/s, offset=165]
# coletando:   8%|▊         | 166/2000 [00:18<04:46,  6.39it/s, offset=166]
# coletando:   8%|▊         | 167/2000 [00:18<04:46,  6.39it/s, offset=167]
# coletando:   8%|▊         | 168/2000 [00:18<04:46,  6.39it/s, offset=168]
# coletando:   8%|▊         | 169/2000 [00:18<04:46,  6.39it/s, offset=169]
# coletando:   8%|▊         | 170/2000 [00:18<04:46,  6.39it/s, offset=170]
# coletando:   9%|▊         | 171/2000 [00:18<04:46,  6.39it/s, offset=171]
# coletando:   9%|▊         | 172/2000 [00:18<04:45,  6.39it/s, offset=172]
# coletando:   9%|▊         | 173/2000 [00:18<04:45,  6.39it/s, offset=173]
# coletando:   9%|▊         | 174/2000 [00:18<04:45,  6.39it/s, offset=174]
# coletando:   9%|▉         | 175/2000 [00:18<04:45,  6.39it/s, offset=175]
# coletando:   9%|▉         | 176/2000 [00:18<04:45,  6.39it/s, offset=176]
# coletando:   9%|▉         | 177/2000 [00:18<04:45,  6.39it/s, offset=177]
# coletando:   9%|▉         | 178/2000 [00:18<04:45,  6.39it/s, offset=178]
# coletando:   9%|▉         | 179/2000 [00:18<04:44,  6.39it/s, offset=179]
# coletando:   9%|▉         | 180/2000 [00:18<04:44,  6.39it/s, offset=180]
# coletando:   9%|▉         | 181/2000 [00:18<04:44,  6.39it/s, offset=181]
# coletando:   9%|▉         | 182/2000 [00:18<04:44,  6.39it/s, offset=182]
# coletando:   9%|▉         | 183/2000 [00:18<04:44,  6.39it/s, offset=183]
# coletando:   9%|▉         | 184/2000 [00:18<04:44,  6.39it/s, offset=184]
# coletando:   9%|▉         | 185/2000 [00:18<04:43,  6.39it/s, offset=185]
# coletando:   9%|▉         | 186/2000 [00:18<04:43,  6.39it/s, offset=186]
# coletando:   9%|▉         | 187/2000 [00:18<04:43,  6.39it/s, offset=187]
# coletando:   9%|▉         | 188/2000 [00:18<04:43,  6.39it/s, offset=188]
# coletando:   9%|▉         | 189/2000 [00:18<04:43,  6.39it/s, offset=189]
# coletando:  10%|▉         | 190/2000 [00:18<04:43,  6.39it/s, offset=190]
# coletando:  10%|▉         | 191/2000 [00:18<04:43,  6.39it/s, offset=191]
# coletando:  10%|▉         | 192/2000 [00:18<04:42,  6.39it/s, offset=192]
# coletando:  10%|▉         | 193/2000 [00:18<04:42,  6.39it/s, offset=193]
# coletando:  10%|▉         | 194/2000 [00:18<04:42,  6.39it/s, offset=194]
# coletando:  10%|▉         | 195/2000 [00:18<04:42,  6.39it/s, offset=195]
# coletando:  10%|▉         | 196/2000 [00:18<04:42,  6.39it/s, offset=196]
# coletando:  10%|▉         | 197/2000 [00:18<04:42,  6.39it/s, offset=197]
# coletando:  10%|▉         | 198/2000 [00:18<04:41,  6.39it/s, offset=198]
# coletando:  10%|▉         | 199/2000 [00:18<04:41,  6.39it/s, offset=199]
# coletando:  10%|█         | 200/2000 [00:18<04:41,  6.39it/s, offset=200]
# coletando:  10%|█         | 201/2000 [00:24<04:08,  7.23it/s, offset=200]
# coletando:  10%|█         | 201/2000 [00:24<04:08,  7.23it/s, offset=201]
# coletando:  10%|█         | 202/2000 [00:24<04:08,  7.23it/s, offset=202]
# coletando:  10%|█         | 203/2000 [00:24<04:08,  7.23it/s, offset=203]
# coletando:  10%|█         | 204/2000 [00:24<04:08,  7.23it/s, offset=204]
# coletando:  10%|█         | 205/2000 [00:24<04:08,  7.23it/s, offset=205]
# coletando:  10%|█         | 206/2000 [00:24<04:08,  7.23it/s, offset=206]
# coletando:  10%|█         | 207/2000 [00:24<04:08,  7.23it/s, offset=207]
# coletando:  10%|█         | 208/2000 [00:24<04:07,  7.23it/s, offset=208]
# coletando:  10%|█         | 209/2000 [00:24<04:07,  7.23it/s, offset=209]
# coletando:  10%|█         | 210/2000 [00:24<04:07,  7.23it/s, offset=210]
# coletando:  11%|█         | 211/2000 [00:24<04:07,  7.23it/s, offset=211]
# coletando:  11%|█         | 212/2000 [00:24<04:07,  7.23it/s, offset=212]
# coletando:  11%|█         | 213/2000 [00:24<04:07,  7.23it/s, offset=213]
# coletando:  11%|█         | 214/2000 [00:24<04:07,  7.23it/s, offset=214]
# coletando:  11%|█         | 215/2000 [00:24<04:06,  7.23it/s, offset=215]
# coletando:  11%|█         | 216/2000 [00:24<04:06,  7.23it/s, offset=216]
# coletando:  11%|█         | 217/2000 [00:24<04:06,  7.23it/s, offset=217]
# coletando:  11%|█         | 218/2000 [00:24<04:06,  7.23it/s, offset=218]
# coletando:  11%|█         | 219/2000 [00:24<04:06,  7.23it/s, offset=219]
# coletando:  11%|█         | 220/2000 [00:24<04:06,  7.23it/s, offset=220]
# coletando:  11%|█         | 221/2000 [00:24<04:06,  7.23it/s, offset=221]
# coletando:  11%|█         | 222/2000 [00:24<04:05,  7.23it/s, offset=222]
# coletando:  11%|█         | 223/2000 [00:24<04:05,  7.23it/s, offset=223]
# coletando:  11%|█         | 224/2000 [00:24<04:05,  7.23it/s, offset=224]
# coletando:  11%|█▏        | 225/2000 [00:24<04:05,  7.23it/s, offset=225]
# coletando:  11%|█▏        | 226/2000 [00:24<04:05,  7.23it/s, offset=226]
# coletando:  11%|█▏        | 227/2000 [00:24<04:05,  7.23it/s, offset=227]
# coletando:  11%|█▏        | 228/2000 [00:24<04:05,  7.23it/s, offset=228]
# coletando:  11%|█▏        | 229/2000 [00:24<04:04,  7.23it/s, offset=229]
# coletando:  12%|█▏        | 230/2000 [00:24<04:04,  7.23it/s, offset=230]
# coletando:  12%|█▏        | 231/2000 [00:24<04:04,  7.23it/s, offset=231]
# coletando:  12%|█▏        | 232/2000 [00:24<04:04,  7.23it/s, offset=232]
# coletando:  12%|█▏        | 233/2000 [00:24<04:04,  7.23it/s, offset=233]
# coletando:  12%|█▏        | 234/2000 [00:24<04:04,  7.23it/s, offset=234]
# coletando:  12%|█▏        | 235/2000 [00:24<04:04,  7.23it/s, offset=235]
# coletando:  12%|█▏        | 236/2000 [00:24<04:04,  7.23it/s, offset=236]
# coletando:  12%|█▏        | 237/2000 [00:24<04:03,  7.23it/s, offset=237]
# coletando:  12%|█▏        | 238/2000 [00:24<04:03,  7.23it/s, offset=238]
# coletando:  12%|█▏        | 239/2000 [00:24<04:03,  7.23it/s, offset=239]
# coletando:  12%|█▏        | 240/2000 [00:24<04:03,  7.23it/s, offset=240]
# coletando:  12%|█▏        | 241/2000 [00:24<04:03,  7.23it/s, offset=241]
# coletando:  12%|█▏        | 242/2000 [00:24<04:03,  7.23it/s, offset=242]
# coletando:  12%|█▏        | 243/2000 [00:24<04:03,  7.23it/s, offset=243]
# coletando:  12%|█▏        | 244/2000 [00:24<04:02,  7.23it/s, offset=244]
# coletando:  12%|█▏        | 245/2000 [00:24<04:02,  7.23it/s, offset=245]
# coletando:  12%|█▏        | 246/2000 [00:24<04:02,  7.23it/s, offset=246]
# coletando:  12%|█▏        | 247/2000 [00:24<04:02,  7.23it/s, offset=247]
# coletando:  12%|█▏        | 248/2000 [00:24<04:02,  7.23it/s, offset=248]
# coletando:  12%|█▏        | 249/2000 [00:24<04:02,  7.23it/s, offset=249]
# coletando:  12%|█▎        | 250/2000 [00:24<04:02,  7.23it/s, offset=250]
# coletando:  13%|█▎        | 251/2000 [00:30<03:49,  7.61it/s, offset=250]
# coletando:  13%|█▎        | 251/2000 [00:30<03:49,  7.61it/s, offset=251]
# coletando:  13%|█▎        | 252/2000 [00:30<03:49,  7.61it/s, offset=252]
# coletando:  13%|█▎        | 253/2000 [00:30<03:49,  7.61it/s, offset=253]
# coletando:  13%|█▎        | 254/2000 [00:30<03:49,  7.61it/s, offset=254]
# coletando:  13%|█▎        | 255/2000 [00:30<03:49,  7.61it/s, offset=255]
# coletando:  13%|█▎        | 256/2000 [00:30<03:49,  7.61it/s, offset=256]
# coletando:  13%|█▎        | 257/2000 [00:30<03:48,  7.61it/s, offset=257]
# coletando:  13%|█▎        | 258/2000 [00:30<03:48,  7.61it/s, offset=258]
# coletando:  13%|█▎        | 259/2000 [00:30<03:48,  7.61it/s, offset=259]
# coletando:  13%|█▎        | 260/2000 [00:30<03:48,  7.61it/s, offset=260]
# coletando:  13%|█▎        | 261/2000 [00:30<03:48,  7.61it/s, offset=261]
# coletando:  13%|█▎        | 262/2000 [00:30<03:48,  7.61it/s, offset=262]
# coletando:  13%|█▎        | 263/2000 [00:30<03:48,  7.61it/s, offset=263]
# coletando:  13%|█▎        | 264/2000 [00:30<03:48,  7.61it/s, offset=264]
# coletando:  13%|█▎        | 265/2000 [00:30<03:47,  7.61it/s, offset=265]
# coletando:  13%|█▎        | 266/2000 [00:30<03:47,  7.61it/s, offset=266]
# coletando:  13%|█▎        | 267/2000 [00:30<03:47,  7.61it/s, offset=267]
# coletando:  13%|█▎        | 268/2000 [00:30<03:47,  7.61it/s, offset=268]
# coletando:  13%|█▎        | 269/2000 [00:30<03:47,  7.61it/s, offset=269]
# coletando:  14%|█▎        | 270/2000 [00:30<03:47,  7.61it/s, offset=270]
# coletando:  14%|█▎        | 271/2000 [00:30<03:47,  7.61it/s, offset=271]
# coletando:  14%|█▎        | 272/2000 [00:30<03:46,  7.61it/s, offset=272]
# coletando:  14%|█▎        | 273/2000 [00:30<03:46,  7.61it/s, offset=273]
# coletando:  14%|█▎        | 274/2000 [00:30<03:46,  7.61it/s, offset=274]
# coletando:  14%|█▍        | 275/2000 [00:30<03:46,  7.61it/s, offset=275]
# coletando:  14%|█▍        | 276/2000 [00:30<03:46,  7.61it/s, offset=276]
# coletando:  14%|█▍        | 277/2000 [00:30<03:46,  7.61it/s, offset=277]
# coletando:  14%|█▍        | 278/2000 [00:30<03:46,  7.61it/s, offset=278]
# coletando:  14%|█▍        | 279/2000 [00:30<03:46,  7.61it/s, offset=279]
# coletando:  14%|█▍        | 280/2000 [00:30<03:45,  7.61it/s, offset=280]
# coletando:  14%|█▍        | 281/2000 [00:30<03:45,  7.61it/s, offset=281]
# coletando:  14%|█▍        | 282/2000 [00:30<03:45,  7.61it/s, offset=282]
# coletando:  14%|█▍        | 283/2000 [00:30<03:45,  7.61it/s, offset=283]
# coletando:  14%|█▍        | 284/2000 [00:30<03:45,  7.61it/s, offset=284]
# coletando:  14%|█▍        | 285/2000 [00:30<03:45,  7.61it/s, offset=285]
# coletando:  14%|█▍        | 286/2000 [00:30<03:45,  7.61it/s, offset=286]
# coletando:  14%|█▍        | 287/2000 [00:30<03:45,  7.61it/s, offset=287]
# coletando:  14%|█▍        | 288/2000 [00:30<03:44,  7.61it/s, offset=288]
# coletando:  14%|█▍        | 289/2000 [00:30<03:44,  7.61it/s, offset=289]
# coletando:  14%|█▍        | 290/2000 [00:30<03:44,  7.61it/s, offset=290]
# coletando:  15%|█▍        | 291/2000 [00:30<03:44,  7.61it/s, offset=291]
# coletando:  15%|█▍        | 292/2000 [00:30<03:44,  7.61it/s, offset=292]
# coletando:  15%|█▍        | 293/2000 [00:30<03:44,  7.61it/s, offset=293]
# coletando:  15%|█▍        | 294/2000 [00:30<03:44,  7.61it/s, offset=294]
# coletando:  15%|█▍        | 295/2000 [00:30<03:43,  7.61it/s, offset=295]
# coletando:  15%|█▍        | 296/2000 [00:30<03:43,  7.61it/s, offset=296]
# coletando:  15%|█▍        | 297/2000 [00:30<03:43,  7.61it/s, offset=297]
# coletando:  15%|█▍        | 298/2000 [00:30<03:43,  7.61it/s, offset=298]
# coletando:  15%|█▍        | 299/2000 [00:30<03:43,  7.61it/s, offset=299]
# coletando:  15%|█▌        | 300/2000 [00:30<03:43,  7.61it/s, offset=300]
# coletando:  15%|█▌        | 301/2000 [00:36<03:35,  7.90it/s, offset=300]
# coletando:  15%|█▌        | 301/2000 [00:36<03:35,  7.90it/s, offset=301]
# coletando:  15%|█▌        | 302/2000 [00:36<03:35,  7.90it/s, offset=302]
# coletando:  15%|█▌        | 303/2000 [00:36<03:34,  7.90it/s, offset=303]
# coletando:  15%|█▌        | 304/2000 [00:36<03:34,  7.90it/s, offset=304]
# coletando:  15%|█▌        | 305/2000 [00:36<03:34,  7.90it/s, offset=305]
# coletando:  15%|█▌        | 306/2000 [00:36<03:34,  7.90it/s, offset=306]
# coletando:  15%|█▌        | 307/2000 [00:36<03:34,  7.90it/s, offset=307]
# coletando:  15%|█▌        | 308/2000 [00:36<03:34,  7.90it/s, offset=308]
# coletando:  15%|█▌        | 309/2000 [00:36<03:34,  7.90it/s, offset=309]
# coletando:  16%|█▌        | 310/2000 [00:36<03:33,  7.90it/s, offset=310]
# coletando:  16%|█▌        | 311/2000 [00:36<03:33,  7.90it/s, offset=311]
# coletando:  16%|█▌        | 312/2000 [00:36<03:33,  7.90it/s, offset=312]
# coletando:  16%|█▌        | 313/2000 [00:36<03:33,  7.90it/s, offset=313]
# coletando:  16%|█▌        | 314/2000 [00:36<03:33,  7.90it/s, offset=314]
# coletando:  16%|█▌        | 315/2000 [00:36<03:33,  7.90it/s, offset=315]
# coletando:  16%|█▌        | 316/2000 [00:36<03:33,  7.90it/s, offset=316]
# coletando:  16%|█▌        | 317/2000 [00:36<03:33,  7.90it/s, offset=317]
# coletando:  16%|█▌        | 318/2000 [00:36<03:32,  7.90it/s, offset=318]
# coletando:  16%|█▌        | 319/2000 [00:36<03:32,  7.90it/s, offset=319]
# coletando:  16%|█▌        | 320/2000 [00:36<03:32,  7.90it/s, offset=320]
# coletando:  16%|█▌        | 321/2000 [00:36<03:32,  7.90it/s, offset=321]
# coletando:  16%|█▌        | 322/2000 [00:36<03:32,  7.90it/s, offset=322]
# coletando:  16%|█▌        | 323/2000 [00:36<03:32,  7.90it/s, offset=323]
# coletando:  16%|█▌        | 324/2000 [00:36<03:32,  7.90it/s, offset=324]
# coletando:  16%|█▋        | 325/2000 [00:36<03:32,  7.90it/s, offset=325]
# coletando:  16%|█▋        | 326/2000 [00:36<03:31,  7.90it/s, offset=326]
# coletando:  16%|█▋        | 327/2000 [00:36<03:31,  7.90it/s, offset=327]
# coletando:  16%|█▋        | 328/2000 [00:36<03:31,  7.90it/s, offset=328]
# coletando:  16%|█▋        | 329/2000 [00:36<03:31,  7.90it/s, offset=329]
# coletando:  16%|█▋        | 330/2000 [00:36<03:31,  7.90it/s, offset=330]
# coletando:  17%|█▋        | 331/2000 [00:36<03:31,  7.90it/s, offset=331]
# coletando:  17%|█▋        | 332/2000 [00:36<03:31,  7.90it/s, offset=332]
# coletando:  17%|█▋        | 333/2000 [00:36<03:31,  7.90it/s, offset=333]
# coletando:  17%|█▋        | 334/2000 [00:36<03:30,  7.90it/s, offset=334]
# coletando:  17%|█▋        | 335/2000 [00:36<03:30,  7.90it/s, offset=335]
# coletando:  17%|█▋        | 336/2000 [00:36<03:30,  7.90it/s, offset=336]
# coletando:  17%|█▋        | 337/2000 [00:36<03:30,  7.90it/s, offset=337]
# coletando:  17%|█▋        | 338/2000 [00:36<03:30,  7.90it/s, offset=338]
# coletando:  17%|█▋        | 339/2000 [00:36<03:30,  7.90it/s, offset=339]
# coletando:  17%|█▋        | 340/2000 [00:36<03:30,  7.90it/s, offset=340]
# coletando:  17%|█▋        | 341/2000 [00:36<03:30,  7.90it/s, offset=341]
# coletando:  17%|█▋        | 342/2000 [00:36<03:29,  7.90it/s, offset=342]
# coletando:  17%|█▋        | 343/2000 [00:36<03:29,  7.90it/s, offset=343]
# coletando:  17%|█▋        | 344/2000 [00:36<03:29,  7.90it/s, offset=344]
# coletando:  17%|█▋        | 345/2000 [00:36<03:29,  7.90it/s, offset=345]
# coletando:  17%|█▋        | 346/2000 [00:36<03:29,  7.90it/s, offset=346]
# coletando:  17%|█▋        | 347/2000 [00:36<03:29,  7.90it/s, offset=347]
# coletando:  17%|█▋        | 348/2000 [00:36<03:29,  7.90it/s, offset=348]
# coletando:  17%|█▋        | 349/2000 [00:36<03:29,  7.90it/s, offset=349]
# coletando:  18%|█▊        | 350/2000 [00:36<03:28,  7.90it/s, offset=350]
# coletando:  18%|█▊        | 351/2000 [00:42<03:26,  8.00it/s, offset=350]
# coletando:  18%|█▊        | 351/2000 [00:42<03:26,  8.00it/s, offset=351]
# coletando:  18%|█▊        | 352/2000 [00:42<03:25,  8.00it/s, offset=352]
# coletando:  18%|█▊        | 353/2000 [00:42<03:25,  8.00it/s, offset=353]
# coletando:  18%|█▊        | 354/2000 [00:42<03:25,  8.00it/s, offset=354]
# coletando:  18%|█▊        | 355/2000 [00:42<03:25,  8.00it/s, offset=355]
# coletando:  18%|█▊        | 356/2000 [00:42<03:25,  8.00it/s, offset=356]
# coletando:  18%|█▊        | 357/2000 [00:42<03:25,  8.00it/s, offset=357]
# coletando:  18%|█▊        | 358/2000 [00:42<03:25,  8.00it/s, offset=358]
# coletando:  18%|█▊        | 359/2000 [00:42<03:25,  8.00it/s, offset=359]
# coletando:  18%|█▊        | 360/2000 [00:42<03:24,  8.00it/s, offset=360]
# coletando:  18%|█▊        | 361/2000 [00:42<03:24,  8.00it/s, offset=361]
# coletando:  18%|█▊        | 362/2000 [00:42<03:24,  8.00it/s, offset=362]
# coletando:  18%|█▊        | 363/2000 [00:42<03:24,  8.00it/s, offset=363]
# coletando:  18%|█▊        | 364/2000 [00:42<03:24,  8.00it/s, offset=364]
# coletando:  18%|█▊        | 365/2000 [00:42<03:24,  8.00it/s, offset=365]
# coletando:  18%|█▊        | 366/2000 [00:42<03:24,  8.00it/s, offset=366]
# coletando:  18%|█▊        | 367/2000 [00:42<03:24,  8.00it/s, offset=367]
# coletando:  18%|█▊        | 368/2000 [00:42<03:23,  8.00it/s, offset=368]
# coletando:  18%|█▊        | 369/2000 [00:42<03:23,  8.00it/s, offset=369]
# coletando:  18%|█▊        | 370/2000 [00:42<03:23,  8.00it/s, offset=370]
# coletando:  19%|█▊        | 371/2000 [00:42<03:23,  8.00it/s, offset=371]
# coletando:  19%|█▊        | 372/2000 [00:42<03:23,  8.00it/s, offset=372]
# coletando:  19%|█▊        | 373/2000 [00:42<03:23,  8.00it/s, offset=373]
# coletando:  19%|█▊        | 374/2000 [00:42<03:23,  8.00it/s, offset=374]
# coletando:  19%|█▉        | 375/2000 [00:42<03:23,  8.00it/s, offset=375]
# coletando:  19%|█▉        | 376/2000 [00:42<03:22,  8.00it/s, offset=376]
# coletando:  19%|█▉        | 377/2000 [00:42<03:22,  8.00it/s, offset=377]
# coletando:  19%|█▉        | 378/2000 [00:42<03:22,  8.00it/s, offset=378]
# coletando:  19%|█▉        | 379/2000 [00:42<03:22,  8.00it/s, offset=379]
# coletando:  19%|█▉        | 380/2000 [00:42<03:22,  8.00it/s, offset=380]
# coletando:  19%|█▉        | 381/2000 [00:42<03:22,  8.00it/s, offset=381]
# coletando:  19%|█▉        | 382/2000 [00:42<03:22,  8.00it/s, offset=382]
# coletando:  19%|█▉        | 383/2000 [00:42<03:22,  8.00it/s, offset=383]
# coletando:  19%|█▉        | 384/2000 [00:42<03:21,  8.00it/s, offset=384]
# coletando:  19%|█▉        | 385/2000 [00:42<03:21,  8.00it/s, offset=385]
# coletando:  19%|█▉        | 386/2000 [00:42<03:21,  8.00it/s, offset=386]
# coletando:  19%|█▉        | 387/2000 [00:42<03:21,  8.00it/s, offset=387]
# coletando:  19%|█▉        | 388/2000 [00:42<03:21,  8.00it/s, offset=388]
# coletando:  19%|█▉        | 389/2000 [00:42<03:21,  8.00it/s, offset=389]
# coletando:  20%|█▉        | 390/2000 [00:42<03:21,  8.00it/s, offset=390]
# coletando:  20%|█▉        | 391/2000 [00:42<03:21,  8.00it/s, offset=391]
# coletando:  20%|█▉        | 392/2000 [00:42<03:20,  8.00it/s, offset=392]
# coletando:  20%|█▉        | 393/2000 [00:42<03:20,  8.00it/s, offset=393]
# coletando:  20%|█▉        | 394/2000 [00:42<03:20,  8.00it/s, offset=394]
# coletando:  20%|█▉        | 395/2000 [00:42<03:20,  8.00it/s, offset=395]
# coletando:  20%|█▉        | 396/2000 [00:42<03:20,  8.00it/s, offset=396]
# coletando:  20%|█▉        | 397/2000 [00:42<03:20,  8.00it/s, offset=397]
# coletando:  20%|█▉        | 398/2000 [00:42<03:20,  8.00it/s, offset=398]
# coletando:  20%|█▉        | 399/2000 [00:42<03:20,  8.00it/s, offset=399]
# coletando:  20%|██        | 400/2000 [00:42<03:19,  8.00it/s, offset=400]
# coletando:  20%|██        | 401/2000 [00:48<03:15,  8.19it/s, offset=400]
# coletando:  20%|██        | 401/2000 [00:48<03:15,  8.19it/s, offset=401]
# coletando:  20%|██        | 402/2000 [00:48<03:15,  8.19it/s, offset=402]
# coletando:  20%|██        | 403/2000 [00:48<03:15,  8.19it/s, offset=403]
# coletando:  20%|██        | 404/2000 [00:48<03:14,  8.19it/s, offset=404]
# coletando:  20%|██        | 405/2000 [00:48<03:14,  8.19it/s, offset=405]
# coletando:  20%|██        | 406/2000 [00:48<03:14,  8.19it/s, offset=406]
# coletando:  20%|██        | 407/2000 [00:48<03:14,  8.19it/s, offset=407]
# coletando:  20%|██        | 408/2000 [00:48<03:14,  8.19it/s, offset=408]
# coletando:  20%|██        | 409/2000 [00:48<03:14,  8.19it/s, offset=409]
# coletando:  20%|██        | 410/2000 [00:48<03:14,  8.19it/s, offset=410]
# coletando:  21%|██        | 411/2000 [00:48<03:14,  8.19it/s, offset=411]
# coletando:  21%|██        | 412/2000 [00:48<03:13,  8.19it/s, offset=412]
# coletando:  21%|██        | 413/2000 [00:48<03:13,  8.19it/s, offset=413]
# coletando:  21%|██        | 414/2000 [00:48<03:13,  8.19it/s, offset=414]
# coletando:  21%|██        | 415/2000 [00:48<03:13,  8.19it/s, offset=415]
# coletando:  21%|██        | 416/2000 [00:48<03:13,  8.19it/s, offset=416]
# coletando:  21%|██        | 417/2000 [00:48<03:13,  8.19it/s, offset=417]
# coletando:  21%|██        | 418/2000 [00:48<03:13,  8.19it/s, offset=418]
# coletando:  21%|██        | 419/2000 [00:48<03:13,  8.19it/s, offset=419]
# coletando:  21%|██        | 420/2000 [00:48<03:12,  8.19it/s, offset=420]
# coletando:  21%|██        | 421/2000 [00:48<03:12,  8.19it/s, offset=421]
# coletando:  21%|██        | 422/2000 [00:48<03:12,  8.19it/s, offset=422]
# coletando:  21%|██        | 423/2000 [00:48<03:12,  8.19it/s, offset=423]
# coletando:  21%|██        | 424/2000 [00:48<03:12,  8.19it/s, offset=424]
# coletando:  21%|██▏       | 425/2000 [00:48<03:12,  8.19it/s, offset=425]
# coletando:  21%|██▏       | 426/2000 [00:48<03:12,  8.19it/s, offset=426]
# coletando:  21%|██▏       | 427/2000 [00:48<03:12,  8.19it/s, offset=427]
# coletando:  21%|██▏       | 428/2000 [00:48<03:11,  8.19it/s, offset=428]
# coletando:  21%|██▏       | 429/2000 [00:48<03:11,  8.19it/s, offset=429]
# coletando:  22%|██▏       | 430/2000 [00:48<03:11,  8.19it/s, offset=430]
# coletando:  22%|██▏       | 431/2000 [00:48<03:11,  8.19it/s, offset=431]
# coletando:  22%|██▏       | 432/2000 [00:48<03:11,  8.19it/s, offset=432]
# coletando:  22%|██▏       | 433/2000 [00:48<03:11,  8.19it/s, offset=433]
# coletando:  22%|██▏       | 434/2000 [00:48<03:11,  8.19it/s, offset=434]
# coletando:  22%|██▏       | 435/2000 [00:48<03:11,  8.19it/s, offset=435]
# coletando:  22%|██▏       | 436/2000 [00:48<03:10,  8.19it/s, offset=436]
# coletando:  22%|██▏       | 437/2000 [00:48<03:10,  8.19it/s, offset=437]
# coletando:  22%|██▏       | 438/2000 [00:48<03:10,  8.19it/s, offset=438]
# coletando:  22%|██▏       | 439/2000 [00:48<03:10,  8.19it/s, offset=439]
# coletando:  22%|██▏       | 440/2000 [00:48<03:10,  8.19it/s, offset=440]
# coletando:  22%|██▏       | 441/2000 [00:48<03:10,  8.19it/s, offset=441]
# coletando:  22%|██▏       | 442/2000 [00:48<03:10,  8.19it/s, offset=442]
# coletando:  22%|██▏       | 443/2000 [00:48<03:10,  8.19it/s, offset=443]
# coletando:  22%|██▏       | 444/2000 [00:48<03:10,  8.19it/s, offset=444]
# coletando:  22%|██▏       | 445/2000 [00:48<03:09,  8.19it/s, offset=445]
# coletando:  22%|██▏       | 446/2000 [00:48<03:09,  8.19it/s, offset=446]
# coletando:  22%|██▏       | 447/2000 [00:48<03:09,  8.19it/s, offset=447]
# coletando:  22%|██▏       | 448/2000 [00:48<03:09,  8.19it/s, offset=448]
# coletando:  22%|██▏       | 449/2000 [00:48<03:09,  8.19it/s, offset=449]
# coletando:  22%|██▎       | 450/2000 [00:48<03:09,  8.19it/s, offset=450]
# coletando:  23%|██▎       | 451/2000 [00:54<03:08,  8.23it/s, offset=450]
# coletando:  23%|██▎       | 451/2000 [00:54<03:08,  8.23it/s, offset=451]
# coletando:  23%|██▎       | 452/2000 [00:54<03:08,  8.23it/s, offset=452]
# coletando:  23%|██▎       | 453/2000 [00:54<03:07,  8.23it/s, offset=453]
# coletando:  23%|██▎       | 454/2000 [00:54<03:07,  8.23it/s, offset=454]
# coletando:  23%|██▎       | 455/2000 [00:54<03:07,  8.23it/s, offset=455]
# coletando:  23%|██▎       | 456/2000 [00:54<03:07,  8.23it/s, offset=456]
# coletando:  23%|██▎       | 457/2000 [00:54<03:07,  8.23it/s, offset=457]
# coletando:  23%|██▎       | 458/2000 [00:54<03:07,  8.23it/s, offset=458]
# coletando:  23%|██▎       | 459/2000 [00:54<03:07,  8.23it/s, offset=459]
# coletando:  23%|██▎       | 460/2000 [00:54<03:07,  8.23it/s, offset=460]
# coletando:  23%|██▎       | 461/2000 [00:54<03:06,  8.23it/s, offset=461]
# coletando:  23%|██▎       | 462/2000 [00:54<03:06,  8.23it/s, offset=462]
# coletando:  23%|██▎       | 463/2000 [00:54<03:06,  8.23it/s, offset=463]
# coletando:  23%|██▎       | 464/2000 [00:54<03:06,  8.23it/s, offset=464]
# coletando:  23%|██▎       | 465/2000 [00:54<03:06,  8.23it/s, offset=465]
# coletando:  23%|██▎       | 466/2000 [00:54<03:06,  8.23it/s, offset=466]
# coletando:  23%|██▎       | 467/2000 [00:54<03:06,  8.23it/s, offset=467]
# coletando:  23%|██▎       | 468/2000 [00:54<03:06,  8.23it/s, offset=468]
# coletando:  23%|██▎       | 469/2000 [00:54<03:05,  8.23it/s, offset=469]
# coletando:  24%|██▎       | 470/2000 [00:54<03:05,  8.23it/s, offset=470]
# coletando:  24%|██▎       | 471/2000 [00:54<03:05,  8.23it/s, offset=471]
# coletando:  24%|██▎       | 472/2000 [00:54<03:05,  8.23it/s, offset=472]
# coletando:  24%|██▎       | 473/2000 [00:54<03:05,  8.23it/s, offset=473]
# coletando:  24%|██▎       | 474/2000 [00:54<03:05,  8.23it/s, offset=474]
# coletando:  24%|██▍       | 475/2000 [00:54<03:05,  8.23it/s, offset=475]
# coletando:  24%|██▍       | 476/2000 [00:54<03:05,  8.23it/s, offset=476]
# coletando:  24%|██▍       | 477/2000 [00:54<03:04,  8.23it/s, offset=477]
# coletando:  24%|██▍       | 478/2000 [00:54<03:04,  8.23it/s, offset=478]
# coletando:  24%|██▍       | 479/2000 [00:54<03:04,  8.23it/s, offset=479]
# coletando:  24%|██▍       | 480/2000 [00:54<03:04,  8.23it/s, offset=480]
# coletando:  24%|██▍       | 481/2000 [00:54<03:04,  8.23it/s, offset=481]
# coletando:  24%|██▍       | 482/2000 [00:54<03:04,  8.23it/s, offset=482]
# coletando:  24%|██▍       | 483/2000 [00:54<03:04,  8.23it/s, offset=483]
# coletando:  24%|██▍       | 484/2000 [00:54<03:04,  8.23it/s, offset=484]
# coletando:  24%|██▍       | 485/2000 [00:54<03:04,  8.23it/s, offset=485]
# coletando:  24%|██▍       | 486/2000 [00:54<03:03,  8.23it/s, offset=486]
# coletando:  24%|██▍       | 487/2000 [00:54<03:03,  8.23it/s, offset=487]
# coletando:  24%|██▍       | 488/2000 [00:54<03:03,  8.23it/s, offset=488]
# coletando:  24%|██▍       | 489/2000 [00:54<03:03,  8.23it/s, offset=489]
# coletando:  24%|██▍       | 490/2000 [00:54<03:03,  8.23it/s, offset=490]
# coletando:  25%|██▍       | 491/2000 [00:54<03:03,  8.23it/s, offset=491]
# coletando:  25%|██▍       | 492/2000 [00:54<03:03,  8.23it/s, offset=492]
# coletando:  25%|██▍       | 493/2000 [00:54<03:03,  8.23it/s, offset=493]
# coletando:  25%|██▍       | 494/2000 [00:54<03:02,  8.23it/s, offset=494]
# coletando:  25%|██▍       | 495/2000 [00:54<03:02,  8.23it/s, offset=495]
# coletando:  25%|██▍       | 496/2000 [00:54<03:02,  8.23it/s, offset=496]
# coletando:  25%|██▍       | 497/2000 [00:54<03:02,  8.23it/s, offset=497]
# coletando:  25%|██▍       | 498/2000 [00:54<03:02,  8.23it/s, offset=498]
# coletando:  25%|██▍       | 499/2000 [00:54<03:02,  8.23it/s, offset=499]
# coletando:  25%|██▌       | 500/2000 [00:54<03:02,  8.23it/s, offset=500]
# coletando:  25%|██▌       | 501/2000 [00:59<03:00,  8.28it/s, offset=500]
# coletando:  25%|██▌       | 501/2000 [00:59<03:00,  8.28it/s, offset=501]
# coletando:  25%|██▌       | 502/2000 [00:59<03:00,  8.28it/s, offset=502]
# coletando:  25%|██▌       | 503/2000 [00:59<03:00,  8.28it/s, offset=503]
# coletando:  25%|██▌       | 504/2000 [00:59<03:00,  8.28it/s, offset=504]
# coletando:  25%|██▌       | 505/2000 [00:59<03:00,  8.28it/s, offset=505]
# coletando:  25%|██▌       | 506/2000 [00:59<03:00,  8.28it/s, offset=506]
# coletando:  25%|██▌       | 507/2000 [00:59<03:00,  8.28it/s, offset=507]
# coletando:  25%|██▌       | 508/2000 [00:59<03:00,  8.28it/s, offset=508]
# coletando:  25%|██▌       | 509/2000 [00:59<02:59,  8.28it/s, offset=509]
# coletando:  26%|██▌       | 510/2000 [00:59<02:59,  8.28it/s, offset=510]
# coletando:  26%|██▌       | 511/2000 [00:59<02:59,  8.28it/s, offset=511]
# coletando:  26%|██▌       | 512/2000 [00:59<02:59,  8.28it/s, offset=512]
# coletando:  26%|██▌       | 513/2000 [00:59<02:59,  8.28it/s, offset=513]
# coletando:  26%|██▌       | 514/2000 [00:59<02:59,  8.28it/s, offset=514]
# coletando:  26%|██▌       | 515/2000 [00:59<02:59,  8.28it/s, offset=515]
# coletando:  26%|██▌       | 516/2000 [00:59<02:59,  8.28it/s, offset=516]
# coletando:  26%|██▌       | 517/2000 [00:59<02:59,  8.28it/s, offset=517]
# coletando:  26%|██▌       | 518/2000 [00:59<02:58,  8.28it/s, offset=518]
# coletando:  26%|██▌       | 519/2000 [00:59<02:58,  8.28it/s, offset=519]
# coletando:  26%|██▌       | 520/2000 [00:59<02:58,  8.28it/s, offset=520]
# coletando:  26%|██▌       | 521/2000 [00:59<02:58,  8.28it/s, offset=521]
# coletando:  26%|██▌       | 522/2000 [00:59<02:58,  8.28it/s, offset=522]
# coletando:  26%|██▌       | 523/2000 [00:59<02:58,  8.28it/s, offset=523]
# coletando:  26%|██▌       | 524/2000 [00:59<02:58,  8.28it/s, offset=524]
# coletando:  26%|██▋       | 525/2000 [00:59<02:58,  8.28it/s, offset=525]
# coletando:  26%|██▋       | 526/2000 [00:59<02:57,  8.28it/s, offset=526]
# coletando:  26%|██▋       | 527/2000 [00:59<02:57,  8.28it/s, offset=527]
# coletando:  26%|██▋       | 528/2000 [00:59<02:57,  8.28it/s, offset=528]
# coletando:  26%|██▋       | 529/2000 [00:59<02:57,  8.28it/s, offset=529]
# coletando:  26%|██▋       | 530/2000 [00:59<02:57,  8.28it/s, offset=530]
# coletando:  27%|██▋       | 531/2000 [00:59<02:57,  8.28it/s, offset=531]
# coletando:  27%|██▋       | 532/2000 [01:00<02:57,  8.28it/s, offset=532]
# coletando:  27%|██▋       | 533/2000 [01:00<02:57,  8.28it/s, offset=533]
# coletando:  27%|██▋       | 534/2000 [01:00<02:56,  8.28it/s, offset=534]
# coletando:  27%|██▋       | 535/2000 [01:00<02:56,  8.28it/s, offset=535]
# coletando:  27%|██▋       | 536/2000 [01:00<02:56,  8.28it/s, offset=536]
# coletando:  27%|██▋       | 537/2000 [01:00<02:56,  8.28it/s, offset=537]
# coletando:  27%|██▋       | 538/2000 [01:00<02:56,  8.28it/s, offset=538]
# coletando:  27%|██▋       | 539/2000 [01:00<02:56,  8.28it/s, offset=539]
# coletando:  27%|██▋       | 540/2000 [01:00<02:56,  8.28it/s, offset=540]
# coletando:  27%|██▋       | 541/2000 [01:00<02:56,  8.28it/s, offset=541]
# coletando:  27%|██▋       | 542/2000 [01:00<02:55,  8.28it/s, offset=542]
# coletando:  27%|██▋       | 543/2000 [01:00<02:55,  8.28it/s, offset=543]
# coletando:  27%|██▋       | 544/2000 [01:00<02:55,  8.28it/s, offset=544]
# coletando:  27%|██▋       | 545/2000 [01:00<02:55,  8.28it/s, offset=545]
# coletando:  27%|██▋       | 546/2000 [01:00<02:55,  8.28it/s, offset=546]
# coletando:  27%|██▋       | 547/2000 [01:00<02:55,  8.28it/s, offset=547]
# coletando:  27%|██▋       | 548/2000 [01:00<02:55,  8.28it/s, offset=548]
# coletando:  27%|██▋       | 549/2000 [01:00<02:55,  8.28it/s, offset=549]
# coletando:  28%|██▊       | 550/2000 [01:00<02:55,  8.28it/s, offset=550]
# coletando:  28%|██▊       | 551/2000 [01:06<02:55,  8.24it/s, offset=550]
# coletando:  28%|██▊       | 551/2000 [01:06<02:55,  8.24it/s, offset=551]
# coletando:  28%|██▊       | 552/2000 [01:06<02:55,  8.24it/s, offset=552]
# coletando:  28%|██▊       | 553/2000 [01:06<02:55,  8.24it/s, offset=553]
# coletando:  28%|██▊       | 554/2000 [01:06<02:55,  8.24it/s, offset=554]
# coletando:  28%|██▊       | 555/2000 [01:06<02:55,  8.24it/s, offset=555]
# coletando:  28%|██▊       | 556/2000 [01:06<02:55,  8.24it/s, offset=556]
# coletando:  28%|██▊       | 557/2000 [01:06<02:55,  8.24it/s, offset=557]
# coletando:  28%|██▊       | 558/2000 [01:06<02:55,  8.24it/s, offset=558]
# coletando:  28%|██▊       | 559/2000 [01:06<02:54,  8.24it/s, offset=559]
# coletando:  28%|██▊       | 560/2000 [01:06<02:54,  8.24it/s, offset=560]
# coletando:  28%|██▊       | 561/2000 [01:06<02:54,  8.24it/s, offset=561]
# coletando:  28%|██▊       | 562/2000 [01:06<02:54,  8.24it/s, offset=562]
# coletando:  28%|██▊       | 563/2000 [01:06<02:54,  8.24it/s, offset=563]
# coletando:  28%|██▊       | 564/2000 [01:06<02:54,  8.24it/s, offset=564]
# coletando:  28%|██▊       | 565/2000 [01:06<02:54,  8.24it/s, offset=565]
# coletando:  28%|██▊       | 566/2000 [01:06<02:54,  8.24it/s, offset=566]
# coletando:  28%|██▊       | 567/2000 [01:06<02:53,  8.24it/s, offset=567]
# coletando:  28%|██▊       | 568/2000 [01:06<02:53,  8.24it/s, offset=568]
# coletando:  28%|██▊       | 569/2000 [01:06<02:53,  8.24it/s, offset=569]
# coletando:  28%|██▊       | 570/2000 [01:06<02:53,  8.24it/s, offset=570]
# coletando:  29%|██▊       | 571/2000 [01:06<02:53,  8.24it/s, offset=571]
# coletando:  29%|██▊       | 572/2000 [01:06<02:53,  8.24it/s, offset=572]
# coletando:  29%|██▊       | 573/2000 [01:06<02:53,  8.24it/s, offset=573]
# coletando:  29%|██▊       | 574/2000 [01:06<02:53,  8.24it/s, offset=574]
# coletando:  29%|██▉       | 575/2000 [01:06<02:52,  8.24it/s, offset=575]
# coletando:  29%|██▉       | 576/2000 [01:06<02:52,  8.24it/s, offset=576]
# coletando:  29%|██▉       | 577/2000 [01:06<02:52,  8.24it/s, offset=577]
# coletando:  29%|██▉       | 578/2000 [01:06<02:52,  8.24it/s, offset=578]
# coletando:  29%|██▉       | 579/2000 [01:06<02:52,  8.24it/s, offset=579]
# coletando:  29%|██▉       | 580/2000 [01:06<02:52,  8.24it/s, offset=580]
# coletando:  29%|██▉       | 581/2000 [01:06<02:52,  8.24it/s, offset=581]
# coletando:  29%|██▉       | 582/2000 [01:06<02:52,  8.24it/s, offset=582]
# coletando:  29%|██▉       | 583/2000 [01:06<02:51,  8.24it/s, offset=583]
# coletando:  29%|██▉       | 584/2000 [01:06<02:51,  8.24it/s, offset=584]
# coletando:  29%|██▉       | 585/2000 [01:06<02:51,  8.24it/s, offset=585]
# coletando:  29%|██▉       | 586/2000 [01:06<02:51,  8.24it/s, offset=586]
# coletando:  29%|██▉       | 587/2000 [01:06<02:51,  8.24it/s, offset=587]
# coletando:  29%|██▉       | 588/2000 [01:06<02:51,  8.24it/s, offset=588]
# coletando:  29%|██▉       | 589/2000 [01:06<02:51,  8.24it/s, offset=589]
# coletando:  30%|██▉       | 590/2000 [01:06<02:51,  8.24it/s, offset=590]
# coletando:  30%|██▉       | 591/2000 [01:06<02:51,  8.24it/s, offset=591]
# coletando:  30%|██▉       | 592/2000 [01:06<02:50,  8.24it/s, offset=592]
# coletando:  30%|██▉       | 593/2000 [01:06<02:50,  8.24it/s, offset=593]
# coletando:  30%|██▉       | 594/2000 [01:06<02:50,  8.24it/s, offset=594]
# coletando:  30%|██▉       | 595/2000 [01:06<02:50,  8.24it/s, offset=595]
# coletando:  30%|██▉       | 596/2000 [01:06<02:50,  8.24it/s, offset=596]
# coletando:  30%|██▉       | 597/2000 [01:06<02:50,  8.24it/s, offset=597]
# coletando:  30%|██▉       | 598/2000 [01:06<02:50,  8.24it/s, offset=598]
# coletando:  30%|██▉       | 599/2000 [01:06<02:50,  8.24it/s, offset=599]
# coletando:  30%|███       | 600/2000 [01:06<02:49,  8.24it/s, offset=600]
# coletando:  30%|███       | 601/2000 [01:12<02:48,  8.30it/s, offset=600]
# coletando:  30%|███       | 601/2000 [01:12<02:48,  8.30it/s, offset=601]
# coletando:  30%|███       | 602/2000 [01:12<02:48,  8.30it/s, offset=602]
# coletando:  30%|███       | 603/2000 [01:12<02:48,  8.30it/s, offset=603]
# coletando:  30%|███       | 604/2000 [01:12<02:48,  8.30it/s, offset=604]
# coletando:  30%|███       | 605/2000 [01:12<02:48,  8.30it/s, offset=605]
# coletando:  30%|███       | 606/2000 [01:12<02:47,  8.30it/s, offset=606]
# coletando:  30%|███       | 607/2000 [01:12<02:47,  8.30it/s, offset=607]
# coletando:  30%|███       | 608/2000 [01:12<02:47,  8.30it/s, offset=608]
# coletando:  30%|███       | 609/2000 [01:12<02:47,  8.30it/s, offset=609]
# coletando:  30%|███       | 610/2000 [01:12<02:47,  8.30it/s, offset=610]
# coletando:  31%|███       | 611/2000 [01:12<02:47,  8.30it/s, offset=611]
# coletando:  31%|███       | 612/2000 [01:12<02:47,  8.30it/s, offset=612]
# coletando:  31%|███       | 613/2000 [01:12<02:47,  8.30it/s, offset=613]
# coletando:  31%|███       | 614/2000 [01:12<02:47,  8.30it/s, offset=614]
# coletando:  31%|███       | 615/2000 [01:12<02:46,  8.30it/s, offset=615]
# coletando:  31%|███       | 616/2000 [01:12<02:46,  8.30it/s, offset=616]
# coletando:  31%|███       | 617/2000 [01:12<02:46,  8.30it/s, offset=617]
# coletando:  31%|███       | 618/2000 [01:12<02:46,  8.30it/s, offset=618]
# coletando:  31%|███       | 619/2000 [01:12<02:46,  8.30it/s, offset=619]
# coletando:  31%|███       | 620/2000 [01:12<02:46,  8.30it/s, offset=620]
# coletando:  31%|███       | 621/2000 [01:12<02:46,  8.30it/s, offset=621]
# coletando:  31%|███       | 622/2000 [01:12<02:46,  8.30it/s, offset=622]
# coletando:  31%|███       | 623/2000 [01:12<02:45,  8.30it/s, offset=623]
# coletando:  31%|███       | 624/2000 [01:12<02:45,  8.30it/s, offset=624]
# coletando:  31%|███▏      | 625/2000 [01:12<02:45,  8.30it/s, offset=625]
# coletando:  31%|███▏      | 626/2000 [01:12<02:45,  8.30it/s, offset=626]
# coletando:  31%|███▏      | 627/2000 [01:12<02:45,  8.30it/s, offset=627]
# coletando:  31%|███▏      | 628/2000 [01:12<02:45,  8.30it/s, offset=628]
# coletando:  31%|███▏      | 629/2000 [01:12<02:45,  8.30it/s, offset=629]
# coletando:  32%|███▏      | 630/2000 [01:12<02:45,  8.30it/s, offset=630]
# coletando:  32%|███▏      | 631/2000 [01:12<02:44,  8.30it/s, offset=631]
# coletando:  32%|███▏      | 632/2000 [01:12<02:44,  8.30it/s, offset=632]
# coletando:  32%|███▏      | 633/2000 [01:12<02:44,  8.30it/s, offset=633]
# coletando:  32%|███▏      | 634/2000 [01:12<02:44,  8.30it/s, offset=634]
# coletando:  32%|███▏      | 635/2000 [01:12<02:44,  8.30it/s, offset=635]
# coletando:  32%|███▏      | 636/2000 [01:12<02:44,  8.30it/s, offset=636]
# coletando:  32%|███▏      | 637/2000 [01:12<02:44,  8.30it/s, offset=637]
# coletando:  32%|███▏      | 638/2000 [01:12<02:44,  8.30it/s, offset=638]
# coletando:  32%|███▏      | 639/2000 [01:12<02:44,  8.30it/s, offset=639]
# coletando:  32%|███▏      | 640/2000 [01:12<02:43,  8.30it/s, offset=640]
# coletando:  32%|███▏      | 641/2000 [01:12<02:43,  8.30it/s, offset=641]
# coletando:  32%|███▏      | 642/2000 [01:12<02:43,  8.30it/s, offset=642]
# coletando:  32%|███▏      | 643/2000 [01:12<02:43,  8.30it/s, offset=643]
# coletando:  32%|███▏      | 644/2000 [01:12<02:43,  8.30it/s, offset=644]
# coletando:  32%|███▏      | 645/2000 [01:12<02:43,  8.30it/s, offset=645]
# coletando:  32%|███▏      | 646/2000 [01:12<02:43,  8.30it/s, offset=646]
# coletando:  32%|███▏      | 647/2000 [01:12<02:43,  8.30it/s, offset=647]
# coletando:  32%|███▏      | 648/2000 [01:12<02:42,  8.30it/s, offset=648]
# coletando:  32%|███▏      | 649/2000 [01:12<02:42,  8.30it/s, offset=649]
# coletando:  32%|███▎      | 650/2000 [01:12<02:42,  8.30it/s, offset=650]
# coletando:  33%|███▎      | 651/2000 [01:17<02:41,  8.33it/s, offset=650]
# coletando:  33%|███▎      | 651/2000 [01:17<02:41,  8.33it/s, offset=651]
# coletando:  33%|███▎      | 652/2000 [01:17<02:41,  8.33it/s, offset=652]
# coletando:  33%|███▎      | 653/2000 [01:17<02:41,  8.33it/s, offset=653]
# coletando:  33%|███▎      | 654/2000 [01:17<02:41,  8.33it/s, offset=654]
# coletando:  33%|███▎      | 655/2000 [01:17<02:41,  8.33it/s, offset=655]
# coletando:  33%|███▎      | 656/2000 [01:17<02:41,  8.33it/s, offset=656]
# coletando:  33%|███▎      | 657/2000 [01:17<02:41,  8.33it/s, offset=657]
# coletando:  33%|███▎      | 658/2000 [01:17<02:41,  8.33it/s, offset=658]
# coletando:  33%|███▎      | 659/2000 [01:17<02:41,  8.33it/s, offset=659]
# coletando:  33%|███▎      | 660/2000 [01:17<02:40,  8.33it/s, offset=660]
# coletando:  33%|███▎      | 661/2000 [01:17<02:40,  8.33it/s, offset=661]
# coletando:  33%|███▎      | 662/2000 [01:18<02:40,  8.33it/s, offset=662]
# coletando:  33%|███▎      | 663/2000 [01:18<02:40,  8.33it/s, offset=663]
# coletando:  33%|███▎      | 664/2000 [01:18<02:40,  8.33it/s, offset=664]
# coletando:  33%|███▎      | 665/2000 [01:18<02:40,  8.33it/s, offset=665]
# coletando:  33%|███▎      | 666/2000 [01:18<02:40,  8.33it/s, offset=666]
# coletando:  33%|███▎      | 667/2000 [01:18<02:40,  8.33it/s, offset=667]
# coletando:  33%|███▎      | 668/2000 [01:18<02:39,  8.33it/s, offset=668]
# coletando:  33%|███▎      | 669/2000 [01:18<02:39,  8.33it/s, offset=669]
# coletando:  34%|███▎      | 670/2000 [01:18<02:39,  8.33it/s, offset=670]
# coletando:  34%|███▎      | 671/2000 [01:18<02:39,  8.33it/s, offset=671]
# coletando:  34%|███▎      | 672/2000 [01:18<02:39,  8.33it/s, offset=672]
# coletando:  34%|███▎      | 673/2000 [01:18<02:39,  8.33it/s, offset=673]
# coletando:  34%|███▎      | 674/2000 [01:18<02:39,  8.33it/s, offset=674]
# coletando:  34%|███▍      | 675/2000 [01:18<02:39,  8.33it/s, offset=675]
# coletando:  34%|███▍      | 676/2000 [01:18<02:38,  8.33it/s, offset=676]
# coletando:  34%|███▍      | 677/2000 [01:18<02:38,  8.33it/s, offset=677]
# coletando:  34%|███▍      | 678/2000 [01:18<02:38,  8.33it/s, offset=678]
# coletando:  34%|███▍      | 679/2000 [01:18<02:38,  8.33it/s, offset=679]
# coletando:  34%|███▍      | 680/2000 [01:18<02:38,  8.33it/s, offset=680]
# coletando:  34%|███▍      | 681/2000 [01:18<02:38,  8.33it/s, offset=681]
# coletando:  34%|███▍      | 682/2000 [01:18<02:38,  8.33it/s, offset=682]
# coletando:  34%|███▍      | 683/2000 [01:18<02:38,  8.33it/s, offset=683]
# ...
# coletando:  82%|████████▏ | 1645/2000 [03:18<00:44,  7.92it/s, offset=1645]
# coletando:  82%|████████▏ | 1646/2000 [03:18<00:44,  7.92it/s, offset=1646]
# coletando:  82%|████████▏ | 1647/2000 [03:18<00:44,  7.92it/s, offset=1647]
# coletando:  82%|████████▏ | 1648/2000 [03:18<00:44,  7.92it/s, offset=1648]
# coletando:  82%|████████▏ | 1649/2000 [03:18<00:44,  7.92it/s, offset=1649]
# coletando:  82%|████████▎ | 1650/2000 [03:18<00:44,  7.92it/s, offset=1650]
# coletando:  83%|████████▎ | 1651/2000 [03:24<00:43,  8.05it/s, offset=1650]
# coletando:  83%|████████▎ | 1651/2000 [03:24<00:43,  8.05it/s, offset=1651]
# coletando:  83%|████████▎ | 1652/2000 [03:24<00:43,  8.05it/s, offset=1652]
# coletando:  83%|████████▎ | 1653/2000 [03:24<00:43,  8.05it/s, offset=1653]
# coletando:  83%|████████▎ | 1654/2000 [03:24<00:42,  8.05it/s, offset=1654]
# coletando:  83%|████████▎ | 1655/2000 [03:24<00:42,  8.05it/s, offset=1655]
# coletando:  83%|████████▎ | 1656/2000 [03:24<00:42,  8.05it/s, offset=1656]
# coletando:  83%|████████▎ | 1657/2000 [03:24<00:42,  8.05it/s, offset=1657]
# coletando:  83%|████████▎ | 1658/2000 [03:24<00:42,  8.05it/s, offset=1658]
# coletando:  83%|████████▎ | 1659/2000 [03:24<00:42,  8.05it/s, offset=1659]
# coletando:  83%|████████▎ | 1660/2000 [03:24<00:42,  8.05it/s, offset=1660]
# coletando:  83%|████████▎ | 1661/2000 [03:24<00:42,  8.05it/s, offset=1661]
# coletando:  83%|████████▎ | 1662/2000 [03:24<00:41,  8.05it/s, offset=1662]
# coletando:  83%|████████▎ | 1663/2000 [03:24<00:41,  8.05it/s, offset=1663]
# coletando:  83%|████████▎ | 1664/2000 [03:24<00:41,  8.05it/s, offset=1664]
# coletando:  83%|████████▎ | 1665/2000 [03:24<00:41,  8.05it/s, offset=1665]
# coletando:  83%|████████▎ | 1666/2000 [03:24<00:41,  8.05it/s, offset=1666]
# coletando:  83%|████████▎ | 1667/2000 [03:24<00:41,  8.05it/s, offset=1667]
# coletando:  83%|████████▎ | 1668/2000 [03:24<00:41,  8.05it/s, offset=1668]
# coletando:  83%|████████▎ | 1669/2000 [03:24<00:41,  8.05it/s, offset=1669]
# coletando:  84%|████████▎ | 1670/2000 [03:24<00:41,  8.05it/s, offset=1670]
# coletando:  84%|████████▎ | 1671/2000 [03:24<00:40,  8.05it/s, offset=1671]
# coletando:  84%|████████▎ | 1672/2000 [03:24<00:40,  8.05it/s, offset=1672]
# coletando:  84%|████████▎ | 1673/2000 [03:24<00:40,  8.05it/s, offset=1673]
# coletando:  84%|████████▎ | 1674/2000 [03:24<00:40,  8.05it/s, offset=1674]
# coletando:  84%|████████▍ | 1675/2000 [03:24<00:40,  8.05it/s, offset=1675]
# coletando:  84%|████████▍ | 1676/2000 [03:24<00:40,  8.05it/s, offset=1676]
# coletando:  84%|████████▍ | 1677/2000 [03:24<00:40,  8.05it/s, offset=1677]
# coletando:  84%|████████▍ | 1678/2000 [03:24<00:40,  8.05it/s, offset=1678]
# coletando:  84%|████████▍ | 1679/2000 [03:24<00:39,  8.05it/s, offset=1679]
# coletando:  84%|████████▍ | 1680/2000 [03:24<00:39,  8.05it/s, offset=1680]
# coletando:  84%|████████▍ | 1681/2000 [03:24<00:39,  8.05it/s, offset=1681]
# coletando:  84%|████████▍ | 1682/2000 [03:24<00:39,  8.05it/s, offset=1682]
# coletando:  84%|████████▍ | 1683/2000 [03:24<00:39,  8.05it/s, offset=1683]
# coletando:  84%|████████▍ | 1684/2000 [03:24<00:39,  8.05it/s, offset=1684]
# coletando:  84%|████████▍ | 1685/2000 [03:24<00:39,  8.05it/s, offset=1685]
# coletando:  84%|████████▍ | 1686/2000 [03:24<00:39,  8.05it/s, offset=1686]
# coletando:  84%|████████▍ | 1687/2000 [03:24<00:38,  8.05it/s, offset=1687]
# coletando:  84%|████████▍ | 1688/2000 [03:24<00:38,  8.05it/s, offset=1688]
# coletando:  84%|████████▍ | 1689/2000 [03:24<00:38,  8.05it/s, offset=1689]
# coletando:  84%|████████▍ | 1690/2000 [03:24<00:38,  8.05it/s, offset=1690]
# coletando:  85%|████████▍ | 1691/2000 [03:24<00:38,  8.05it/s, offset=1691]
# coletando:  85%|████████▍ | 1692/2000 [03:24<00:38,  8.05it/s, offset=1692]
# coletando:  85%|████████▍ | 1693/2000 [03:24<00:38,  8.05it/s, offset=1693]
# coletando:  85%|████████▍ | 1694/2000 [03:24<00:38,  8.05it/s, offset=1694]
# coletando:  85%|████████▍ | 1695/2000 [03:24<00:37,  8.05it/s, offset=1695]
# coletando:  85%|████████▍ | 1696/2000 [03:24<00:37,  8.05it/s, offset=1696]
# coletando:  85%|████████▍ | 1697/2000 [03:24<00:37,  8.05it/s, offset=1697]
# coletando:  85%|████████▍ | 1698/2000 [03:24<00:37,  8.05it/s, offset=1698]
# coletando:  85%|████████▍ | 1699/2000 [03:24<00:37,  8.05it/s, offset=1699]
# coletando:  85%|████████▌ | 1700/2000 [03:24<00:37,  8.05it/s, offset=1700]
# coletando:  85%|████████▌ | 1701/2000 [03:30<00:36,  8.10it/s, offset=1700]
# coletando:  85%|████████▌ | 1701/2000 [03:30<00:36,  8.10it/s, offset=1701]
# coletando:  85%|████████▌ | 1702/2000 [03:30<00:36,  8.10it/s, offset=1702]
# coletando:  85%|████████▌ | 1703/2000 [03:30<00:36,  8.10it/s, offset=1703]
# coletando:  85%|████████▌ | 1704/2000 [03:30<00:36,  8.10it/s, offset=1704]
# coletando:  85%|████████▌ | 1705/2000 [03:30<00:36,  8.10it/s, offset=1705]
# coletando:  85%|████████▌ | 1706/2000 [03:30<00:36,  8.10it/s, offset=1706]
# coletando:  85%|████████▌ | 1707/2000 [03:30<00:36,  8.10it/s, offset=1707]
# coletando:  85%|████████▌ | 1708/2000 [03:30<00:36,  8.10it/s, offset=1708]
# coletando:  85%|████████▌ | 1709/2000 [03:30<00:35,  8.10it/s, offset=1709]
# coletando:  86%|████████▌ | 1710/2000 [03:30<00:35,  8.10it/s, offset=1710]
# coletando:  86%|████████▌ | 1711/2000 [03:30<00:35,  8.10it/s, offset=1711]
# coletando:  86%|████████▌ | 1712/2000 [03:30<00:35,  8.10it/s, offset=1712]
# coletando:  86%|████████▌ | 1713/2000 [03:30<00:35,  8.10it/s, offset=1713]
# coletando:  86%|████████▌ | 1714/2000 [03:30<00:35,  8.10it/s, offset=1714]
# coletando:  86%|████████▌ | 1715/2000 [03:30<00:35,  8.10it/s, offset=1715]
# coletando:  86%|████████▌ | 1716/2000 [03:30<00:35,  8.10it/s, offset=1716]
# coletando:  86%|████████▌ | 1717/2000 [03:30<00:34,  8.10it/s, offset=1717]
# coletando:  86%|████████▌ | 1718/2000 [03:30<00:34,  8.10it/s, offset=1718]
# coletando:  86%|████████▌ | 1719/2000 [03:30<00:34,  8.10it/s, offset=1719]
# coletando:  86%|████████▌ | 1720/2000 [03:30<00:34,  8.10it/s, offset=1720]
# coletando:  86%|████████▌ | 1721/2000 [03:30<00:34,  8.10it/s, offset=1721]
# coletando:  86%|████████▌ | 1722/2000 [03:30<00:34,  8.10it/s, offset=1722]
# coletando:  86%|████████▌ | 1723/2000 [03:30<00:34,  8.10it/s, offset=1723]
# coletando:  86%|████████▌ | 1724/2000 [03:30<00:34,  8.10it/s, offset=1724]
# coletando:  86%|████████▋ | 1725/2000 [03:30<00:33,  8.10it/s, offset=1725]
# coletando:  86%|████████▋ | 1726/2000 [03:30<00:33,  8.10it/s, offset=1726]
# coletando:  86%|████████▋ | 1727/2000 [03:30<00:33,  8.10it/s, offset=1727]
# coletando:  86%|████████▋ | 1728/2000 [03:30<00:33,  8.10it/s, offset=1728]
# coletando:  86%|████████▋ | 1729/2000 [03:30<00:33,  8.10it/s, offset=1729]
# coletando:  86%|████████▋ | 1730/2000 [03:30<00:33,  8.10it/s, offset=1730]
# coletando:  87%|████████▋ | 1731/2000 [03:30<00:33,  8.10it/s, offset=1731]
# coletando:  87%|████████▋ | 1732/2000 [03:30<00:33,  8.10it/s, offset=1732]
# coletando:  87%|████████▋ | 1733/2000 [03:30<00:32,  8.10it/s, offset=1733]
# coletando:  87%|████████▋ | 1734/2000 [03:30<00:32,  8.10it/s, offset=1734]
# coletando:  87%|████████▋ | 1735/2000 [03:30<00:32,  8.10it/s, offset=1735]
# coletando:  87%|████████▋ | 1736/2000 [03:30<00:32,  8.10it/s, offset=1736]
# coletando:  87%|████████▋ | 1737/2000 [03:30<00:32,  8.10it/s, offset=1737]
# coletando:  87%|████████▋ | 1738/2000 [03:30<00:32,  8.10it/s, offset=1738]
# coletando:  87%|████████▋ | 1739/2000 [03:30<00:32,  8.10it/s, offset=1739]
# coletando:  87%|████████▋ | 1740/2000 [03:30<00:32,  8.10it/s, offset=1740]
# coletando:  87%|████████▋ | 1741/2000 [03:30<00:31,  8.10it/s, offset=1741]
# coletando:  87%|████████▋ | 1742/2000 [03:30<00:31,  8.10it/s, offset=1742]
# coletando:  87%|████████▋ | 1743/2000 [03:30<00:31,  8.10it/s, offset=1743]
# coletando:  87%|████████▋ | 1744/2000 [03:30<00:31,  8.10it/s, offset=1744]
# coletando:  87%|████████▋ | 1745/2000 [03:30<00:31,  8.10it/s, offset=1745]
# coletando:  87%|████████▋ | 1746/2000 [03:30<00:31,  8.10it/s, offset=1746]
# coletando:  87%|████████▋ | 1747/2000 [03:30<00:31,  8.10it/s, offset=1747]
# coletando:  87%|████████▋ | 1748/2000 [03:30<00:31,  8.10it/s, offset=1748]
# coletando:  87%|████████▋ | 1749/2000 [03:30<00:30,  8.10it/s, offset=1749]
# coletando:  88%|████████▊ | 1750/2000 [03:30<00:30,  8.10it/s, offset=1750]
# coletando:  88%|████████▊ | 1751/2000 [03:36<00:31,  7.98it/s, offset=1750]
# coletando:  88%|████████▊ | 1751/2000 [03:36<00:31,  7.98it/s, offset=1751]
# coletando:  88%|████████▊ | 1752/2000 [03:36<00:31,  7.98it/s, offset=1752]
# coletando:  88%|████████▊ | 1753/2000 [03:36<00:30,  7.98it/s, offset=1753]
# coletando:  88%|████████▊ | 1754/2000 [03:36<00:30,  7.98it/s, offset=1754]
# coletando:  88%|████████▊ | 1755/2000 [03:36<00:30,  7.98it/s, offset=1755]
# coletando:  88%|████████▊ | 1756/2000 [03:36<00:30,  7.98it/s, offset=1756]
# coletando:  88%|████████▊ | 1757/2000 [03:36<00:30,  7.98it/s, offset=1757]
# coletando:  88%|████████▊ | 1758/2000 [03:36<00:30,  7.98it/s, offset=1758]
# coletando:  88%|████████▊ | 1759/2000 [03:36<00:30,  7.98it/s, offset=1759]
# coletando:  88%|████████▊ | 1760/2000 [03:36<00:30,  7.98it/s, offset=1760]
# coletando:  88%|████████▊ | 1761/2000 [03:36<00:29,  7.98it/s, offset=1761]
# coletando:  88%|████████▊ | 1762/2000 [03:36<00:29,  7.98it/s, offset=1762]
# coletando:  88%|████████▊ | 1763/2000 [03:36<00:29,  7.98it/s, offset=1763]
# coletando:  88%|████████▊ | 1764/2000 [03:36<00:29,  7.98it/s, offset=1764]
# coletando:  88%|████████▊ | 1765/2000 [03:36<00:29,  7.98it/s, offset=1765]
# coletando:  88%|████████▊ | 1766/2000 [03:36<00:29,  7.98it/s, offset=1766]
# coletando:  88%|████████▊ | 1767/2000 [03:36<00:29,  7.98it/s, offset=1767]
# coletando:  88%|████████▊ | 1768/2000 [03:36<00:29,  7.98it/s, offset=1768]
# coletando:  88%|████████▊ | 1769/2000 [03:36<00:28,  7.98it/s, offset=1769]
# coletando:  88%|████████▊ | 1770/2000 [03:36<00:28,  7.98it/s, offset=1770]
# coletando:  89%|████████▊ | 1771/2000 [03:36<00:28,  7.98it/s, offset=1771]
# coletando:  89%|████████▊ | 1772/2000 [03:36<00:28,  7.98it/s, offset=1772]
# coletando:  89%|████████▊ | 1773/2000 [03:36<00:28,  7.98it/s, offset=1773]
# coletando:  89%|████████▊ | 1774/2000 [03:36<00:28,  7.98it/s, offset=1774]
# coletando:  89%|████████▉ | 1775/2000 [03:36<00:28,  7.98it/s, offset=1775]
# coletando:  89%|████████▉ | 1776/2000 [03:36<00:28,  7.98it/s, offset=1776]
# coletando:  89%|████████▉ | 1777/2000 [03:36<00:27,  7.98it/s, offset=1777]
# coletando:  89%|████████▉ | 1778/2000 [03:36<00:27,  7.98it/s, offset=1778]
# coletando:  89%|████████▉ | 1779/2000 [03:36<00:27,  7.98it/s, offset=1779]
# coletando:  89%|████████▉ | 1780/2000 [03:36<00:27,  7.98it/s, offset=1780]
# coletando:  89%|████████▉ | 1781/2000 [03:36<00:27,  7.98it/s, offset=1781]
# coletando:  89%|████████▉ | 1782/2000 [03:36<00:27,  7.98it/s, offset=1782]
# coletando:  89%|████████▉ | 1783/2000 [03:36<00:27,  7.98it/s, offset=1783]
# coletando:  89%|████████▉ | 1784/2000 [03:36<00:27,  7.98it/s, offset=1784]
# coletando:  89%|████████▉ | 1785/2000 [03:36<00:26,  7.98it/s, offset=1785]
# coletando:  89%|████████▉ | 1786/2000 [03:36<00:26,  7.98it/s, offset=1786]
# coletando:  89%|████████▉ | 1787/2000 [03:36<00:26,  7.98it/s, offset=1787]
# coletando:  89%|████████▉ | 1788/2000 [03:36<00:26,  7.98it/s, offset=1788]
# coletando:  89%|████████▉ | 1789/2000 [03:36<00:26,  7.98it/s, offset=1789]
# coletando:  90%|████████▉ | 1790/2000 [03:36<00:26,  7.98it/s, offset=1790]
# coletando:  90%|████████▉ | 1791/2000 [03:36<00:26,  7.98it/s, offset=1791]
# coletando:  90%|████████▉ | 1792/2000 [03:36<00:26,  7.98it/s, offset=1792]
# coletando:  90%|████████▉ | 1793/2000 [03:36<00:25,  7.98it/s, offset=1793]
# coletando:  90%|████████▉ | 1794/2000 [03:36<00:25,  7.98it/s, offset=1794]
# coletando:  90%|████████▉ | 1795/2000 [03:36<00:25,  7.98it/s, offset=1795]
# coletando:  90%|████████▉ | 1796/2000 [03:36<00:25,  7.98it/s, offset=1796]
# coletando:  90%|████████▉ | 1797/2000 [03:36<00:25,  7.98it/s, offset=1797]
# coletando:  90%|████████▉ | 1798/2000 [03:36<00:25,  7.98it/s, offset=1798]
# coletando:  90%|████████▉ | 1799/2000 [03:36<00:25,  7.98it/s, offset=1799]
# coletando:  90%|█████████ | 1800/2000 [03:36<00:25,  7.98it/s, offset=1800]
# coletando:  90%|█████████ | 1801/2000 [03:43<00:25,  7.88it/s, offset=1800]
# coletando:  90%|█████████ | 1801/2000 [03:43<00:25,  7.88it/s, offset=1801]
# coletando:  90%|█████████ | 1802/2000 [03:43<00:25,  7.88it/s, offset=1802]
# coletando:  90%|█████████ | 1803/2000 [03:43<00:25,  7.88it/s, offset=1803]
# coletando:  90%|█████████ | 1804/2000 [03:43<00:24,  7.88it/s, offset=1804]
# coletando:  90%|█████████ | 1805/2000 [03:43<00:24,  7.88it/s, offset=1805]
# coletando:  90%|█████████ | 1806/2000 [03:43<00:24,  7.88it/s, offset=1806]
# coletando:  90%|█████████ | 1807/2000 [03:43<00:24,  7.88it/s, offset=1807]
# coletando:  90%|█████████ | 1808/2000 [03:43<00:24,  7.88it/s, offset=1808]
# coletando:  90%|█████████ | 1809/2000 [03:43<00:24,  7.88it/s, offset=1809]
# coletando:  90%|█████████ | 1810/2000 [03:43<00:24,  7.88it/s, offset=1810]
# coletando:  91%|█████████ | 1811/2000 [03:43<00:23,  7.88it/s, offset=1811]
# coletando:  91%|█████████ | 1812/2000 [03:43<00:23,  7.88it/s, offset=1812]
# coletando:  91%|█████████ | 1813/2000 [03:43<00:23,  7.88it/s, offset=1813]
# coletando:  91%|█████████ | 1814/2000 [03:43<00:23,  7.88it/s, offset=1814]
# coletando:  91%|█████████ | 1815/2000 [03:43<00:23,  7.88it/s, offset=1815]
# coletando:  91%|█████████ | 1816/2000 [03:43<00:23,  7.88it/s, offset=1816]
# coletando:  91%|█████████ | 1817/2000 [03:43<00:23,  7.88it/s, offset=1817]
# coletando:  91%|█████████ | 1818/2000 [03:43<00:23,  7.88it/s, offset=1818]
# coletando:  91%|█████████ | 1819/2000 [03:43<00:22,  7.88it/s, offset=1819]
# coletando:  91%|█████████ | 1820/2000 [03:43<00:22,  7.88it/s, offset=1820]
# coletando:  91%|█████████ | 1821/2000 [03:43<00:22,  7.88it/s, offset=1821]
# coletando:  91%|█████████ | 1822/2000 [03:43<00:22,  7.88it/s, offset=1822]
# coletando:  91%|█████████ | 1823/2000 [03:43<00:22,  7.88it/s, offset=1823]
# coletando:  91%|█████████ | 1824/2000 [03:43<00:22,  7.88it/s, offset=1824]
# coletando:  91%|█████████▏| 1825/2000 [03:43<00:22,  7.88it/s, offset=1825]
# coletando:  91%|█████████▏| 1826/2000 [03:43<00:22,  7.88it/s, offset=1826]
# coletando:  91%|█████████▏| 1827/2000 [03:43<00:21,  7.88it/s, offset=1827]
# coletando:  91%|█████████▏| 1828/2000 [03:43<00:21,  7.88it/s, offset=1828]
# coletando:  91%|█████████▏| 1829/2000 [03:43<00:21,  7.88it/s, offset=1829]
# coletando:  92%|█████████▏| 1830/2000 [03:43<00:21,  7.88it/s, offset=1830]
# coletando:  92%|█████████▏| 1831/2000 [03:43<00:21,  7.88it/s, offset=1831]
# coletando:  92%|█████████▏| 1832/2000 [03:43<00:21,  7.88it/s, offset=1832]
# coletando:  92%|█████████▏| 1833/2000 [03:43<00:21,  7.88it/s, offset=1833]
# coletando:  92%|█████████▏| 1834/2000 [03:43<00:21,  7.88it/s, offset=1834]
# coletando:  92%|█████████▏| 1835/2000 [03:43<00:20,  7.88it/s, offset=1835]
# coletando:  92%|█████████▏| 1836/2000 [03:43<00:20,  7.88it/s, offset=1836]
# coletando:  92%|█████████▏| 1837/2000 [03:43<00:20,  7.88it/s, offset=1837]
# coletando:  92%|█████████▏| 1838/2000 [03:43<00:20,  7.88it/s, offset=1838]
# coletando:  92%|█████████▏| 1839/2000 [03:43<00:20,  7.88it/s, offset=1839]
# coletando:  92%|█████████▏| 1840/2000 [03:43<00:20,  7.88it/s, offset=1840]
# coletando:  92%|█████████▏| 1841/2000 [03:43<00:20,  7.88it/s, offset=1841]
# coletando:  92%|█████████▏| 1842/2000 [03:43<00:20,  7.88it/s, offset=1842]
# coletando:  92%|█████████▏| 1843/2000 [03:43<00:19,  7.88it/s, offset=1843]
# coletando:  92%|█████████▏| 1844/2000 [03:43<00:19,  7.88it/s, offset=1844]
# coletando:  92%|█████████▏| 1845/2000 [03:43<00:19,  7.88it/s, offset=1845]
# coletando:  92%|█████████▏| 1846/2000 [03:43<00:19,  7.88it/s, offset=1846]
# coletando:  92%|█████████▏| 1847/2000 [03:43<00:19,  7.88it/s, offset=1847]
# coletando:  92%|█████████▏| 1848/2000 [03:43<00:19,  7.88it/s, offset=1848]
# coletando:  92%|█████████▏| 1849/2000 [03:43<00:19,  7.88it/s, offset=1849]
# coletando:  92%|█████████▎| 1850/2000 [03:43<00:19,  7.88it/s, offset=1850]

# %% [markdown]
# ### O que fazer se a coleta continuar falhando
#
# 1. **Espere e tente de novo.** A API do ArXiv pode temporariamente bloquear o seu IP. Aguarde 15--30 min e rode a célula acima novamente --- ela vai retomar.
# 2. **Reduza a query.** Menos `OR` $\Rightarrow$ menos custo no servidor. Tente com 2--3 palavras-chave mais discriminativas.
# 3. **Reduza `PAGE_SIZE`** para 25 (mais requisições, cada uma mais leve).
# 4. **Aumente o `delay_seconds`** do `arxiv.Client` para 10 ou 15 segundos.
# 5. **Plano B: use o *bulk access* do ArXiv** (S3 / Kaggle dump) --- baixa em uma vez só, sem rate limit, ao custo de não ter os artigos mais recentes do dia.
# 6. **Plano C: troque a fonte** para Semantic Scholar, OpenAlex ou DBLP (todas listadas na Seção 5 do enunciado).

# %% [markdown]
# ## 4. Normalização e deduplicação
#
# A coleta bruta pode conter duplicatas (mesmo `arxiv_id` em diferentes versões) ou registros sem abstract. Geramos uma versão limpa em `corpus.jsonl`.

# %%
def load_jsonl(path: Path):
    with open(path, "r", encoding="utf-8") as f:
        return [json.loads(line) for line in f]


raw = load_jsonl(RAW_PATH)
print("Registros brutos:", len(raw))

# Deduplicar por arxiv_id (mantém o mais recente por 'updated').
df = pd.DataFrame(raw)
df["updated_dt"] = pd.to_datetime(df["updated"], errors="coerce")
df = df.sort_values("updated_dt").drop_duplicates("arxiv_id", keep="last")

# Remover registros sem título ou sem abstract.
df = df[df["title"].str.len() > 0]
df = df[df["abstract"].str.len() > 50]  # abstracts muito curtos costumam ser ruído

print("Após deduplicação e limpeza:", len(df))
df.head(3)

# %% [markdown]
# ## 5. Salvamento em `corpus.jsonl`
#
# Este é o arquivo que você vai usar nas próximas etapas (BM25, KNN, etc.).

# %%
cols = ["arxiv_id", "title", "abstract", "authors", "categories",
         "primary_category", "published", "doi", "pdf_url"]

with open(CORPUS_PATH, "w", encoding="utf-8") as f:
    for _, row in df[cols].iterrows():
        f.write(json.dumps(row.to_dict(), ensure_ascii=False) + "\n")

print(f"Corpus salvo em: {CORPUS_PATH} ({len(df)} documentos).")

# %% [markdown]
# ## 6. Verificação rápida da coleção (*sanity checks*)
#
# Antes de partir para a recuperação, dê uma olhada na distribuição temporal, por categoria, e em alguns exemplos. Erros mais comuns: filtros muito apertados (corpus minúsculo), filtros muito frouxos (corpus contaminado com áreas alheias).

# %%
df["year"] = pd.to_datetime(df["published"], errors="coerce").dt.year
print("Distribuição por ano:")
print(df["year"].value_counts().sort_index())
print("\nDistribuição por categoria primária:")
print(df["primary_category"].value_counts().head(10))

# %%
# Exemplos aleatórios para inspeção manual.
for _, row in df.sample(min(3, len(df)), random_state=42).iterrows():
    print("=" * 80)
    print("ID      :", row["arxiv_id"])
    print("Title   :", row["title"])
    print("Cats    :", row["categories"])
    print("Year    :", row["year"])
    print("Abstract:", row["abstract"][:400], "...")
